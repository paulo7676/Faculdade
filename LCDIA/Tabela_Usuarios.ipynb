# %%
import pandas as pd
import pymongo
from bson.objectid import ObjectId
import csv

# %%
data1 = pd.read_csv("Data_2020_Final.csv", encoding = "ISO-8859-1")
data2 = pd.read_csv("Data_2021_Final.csv", encoding = "ISO-8859-1")
usuarios = pd.read_csv("Dados_Usuarios(Certo).csv", encoding = "ISO-8859-1")

usuarios_novos = pd.read_csv("Dados_att5.csv", encoding = "ISO-8859-1")

# %%
usuarios_cadastrados = []
for i in usuarios_novos["Usuario"]:
    usuarios_cadastrados.append(i)

# %%
Usuarios = {}
for i in usuarios["Usuario"]:
    Usuarios[i] = ""

# %%
for i in Usuarios:
    if len(Usuarios[i]) == 0:
        print(i)
# Out:
# metaeconomia1
# Crypto_emrgency
# CryptoTimes_mag
# thesahilsays
# Bitribeofficial
# btc_dakara
# eTalentMoney
# Taour_
# Auntyadaa
# coinpicksjapan
# BuyingEveryDip
# WhaleChart
# TecraSpace
# sametoolz
# kacperski719
# cissan_9984
# 0xglitch_
# bsvscreen
# GemGamenft
# IStandWithPYO
# YieldApp
# skyler_fs
# KoichiTsunoda
# CryptoTrendsz
# yocchan60
# CryptKeeperBTC
# riki_sakamoto
# umbrel
# bigd3bs
# MrShawnRogers
# izzy9821
# murdabeatz
# CryptSpecialist
# twetchapp
# _EmpressSara
# No_Limits060
# lelibertee
# TakaSNSmarke
# rah04444
# onedracokeem
# baylorlandry
# ayomiajiboye_
# sexy_diana1
# stillgray
# JordanSchachtel
# BITCOIN_AL_DIA
# MixtaOlamilekan
# 0xBrk3
# 16doge
# ElTrompudo2022
# MissDemas_
# Oladapomikky1
# empatik
# FrogeFi
# sirbullycrypto
# servicehubb_ng
# TronDao_ESP
# WhaleyEth
# maskthedegen
# kriptosezerbtc
# XRP_Moonshots
# OfflineExchange
# NikolayShkilev
# fxoldman0321
# AshNFT__
# flrfinance
# AbdulkerimSma
# SebSats
# BarachelElihus
# NinoconBarba
# ZinedHodl
# Baris_Sma
# TelcoinCom
# kris
# shibainu_kanko_
# NFTMasterclass
# KanutoTakumi
# EhlenoCrypto
# CryptoBoostMe
# Ben_000777
# blackbeardXBT
# grace_kalbo
# SHIBrumours
# SInvestments2
# kyosantou347
# JoForLiberty
# ineedmoneyxbt
# nuafriksupport
# YemieFash
# nonfungible_eth
# ExcelTrading1
# nayaofficial01
# PaschalNwafor_
# TheIgboWolf
# JED_FUT
# iyaboawokoya
# thetoluoflagos
# chrisnuzi
# afrikantribe
# okx
# reptheset55
# ikbldrs
# Web3Lewis
# BigSammy__
# nukimaruda
# OfficialXRParmy
# JoshChambi_KE
# MoonliftCapital
# evdc_network
# kholiatk
# AirShippedWorld
# aiyshesu
# BankOfIndra
# You_Zan_
# Jason
# honey_xbt
# TheBlockTake
# hiiiiii3333
# SequentialTrade
# OpenNode
# preston_hodl
# xcryptomaniacx
# cponlife
# kaekae_style
# GreffMichael
# NFTBUZZNEWS
# 1rtuMu61pJwZPmF
# Isekai_Verse
# andr3w
# grycrypto
# DigPerspectives
# seidon_mounten_
# Mark_Crypto_off
# Gemzillacrypto
# PowerPixelKK
# BTC_for_Freedom
# rero_teamcrypto
# Roosterpromos
# slavi_io

# %%
for i in range(len(data1)):
    try:
        Usuarios[data1["user"][i].replace("@","")] += (data1["texto"][i].replace("\n", " ") + " ")
    except:
        a = 0
for i in range(len(data2)):
    try:
        Usuarios[data2["user"][i].replace("@","")] += (data2["texto"][i].replace("\n", " ") + " ")
    except:
        a = 0

# %%
len(usuarios_cadastrados)
# Out:
# 946

# %%
from collections import Counter

res = Counter(usuarios_cadastrados)

print(res)
# Out:
# Counter({'pembertonrob': 2, 'amtvmedia': 2, 'thesahilsays': 2, 'Bitribeofficial': 2, 'IndiaAboriginal': 2, 'IvanOnTech': 2, 'indepreserve': 2, 'kerooke': 2, 'BitcoinBF': 2, 'IOHK_Charles': 2, 'coryklippsten': 2, 'Melt_Dem': 2, 'cameron': 2, 'GeoffLewisOrg': 2, 'GiveAndStake': 2, 'HuobiGlobal': 2, 'MMCrypto': 2, 'Breedlove22': 2, 'erikfinman': 2, 'BlvckDotun': 2, 'clarkmoody': 2, 'ScottLEOWarrior': 2, 'TheCryptoLark': 2, 'qtkyoo': 2, 'jimmysong': 2, 'BitcoinIsSaving': 2, 'APompliano': 1, 'CoinCornerDanny': 1, 'AltcoinDailyio': 1, 'nanogamesio': 1, 'cz_binance': 1, 'faveladoinvest': 1, 'DexiveExchange': 1, 'river': 1, 'GoingParabolic': 1, 'CashApp': 1, 'Bitsahara': 1, '100trillionUSD': 1, 'InstaSwap_io': 1, 'rogerkver': 1, 'tyler': 1, 'jack': 1, 'milessuter': 1, 'alistairmilne': 1, 'CoinDesk': 1, 'Bitcoin': 1, 'jchatterleyCNN': 1, 'MsHodl': 1, 'EduardoGavotti': 1, 'naval': 1, 'cryptocom': 1, 'SatoshiLite': 1, 'DTAPCAP': 1, 'PetroDivisa': 1, 'realMatrixport': 1, 'EshaanMenon': 1, 'satomichan0626': 1, 'PixbyToken': 1, 'Suheb__': 1, 'Cryptoking': 1, 'Cointelegraph': 1, 'justinsuntron': 1, 'CaitlinLong_': 1, 'DoveyWan': 1, 'ErikVoorhees': 1, 'charliebilello': 1, 'CNBCFastMoney': 1, 'danheld': 1, 'BithumbGlobal': 1, 'marcopologlobal': 1, 'cobie': 1, 'CryptoBull': 1, 'hodlonaut': 1, 'levijawn': 1, 'NexusOfficial': 1, 'TuurDemeester': 1, 'metaeconomia1': 1, 'MaxieRyan': 1, 'nwankwoesq': 1, 'Crypto_emrgency': 1, 'lopp': 1, 'AtomicWallet': 1, 'CryptoAdventure': 1, 'aantonop': 1, 'jchervinsky': 1, 'rektcapital': 1, 'woonomic': 1, 'crypto_birb': 1, 'TheMoonCarl': 1, 'cryptoshion': 1, 'DraxFTW_': 1, 'CryptoHayes': 1, 'Excellion': 1, 'btc': 1, 'Rhythmtrader': 1, 'nvk': 1, 'scottmelker': 1, 'WhalePanda': 1, 'crypto': 1, 'bgarlinghouse': 1, 'lightning': 1, 'bensemchee': 1, 'ftx_app': 1, 'sosjorginho': 1, 'juanrallo': 1, 'crypt0snews': 1, 'skwp': 1, 'BitShills': 1, 'binance': 1, 'bradmillscan': 1, 'nlw': 1, 'AngeloBTC': 1, 'DigitalAssets': 1, 'ALISON_airlines': 1, 'JoshRoomsburg': 1, 'nandszffc': 1, 'NostalgiaFlu': 1, 'jefimzao': 1, 'realsurgesolar': 1, 'fundstrat': 1, 'officialmcafee': 1, 'ANI': 1, 'RaoulGMI': 1, 'bitcoin_clara': 1, 'LinkupFr': 1, 'Xentagz': 1, 'blingfiapp': 1, 'AlyseKilleen': 1, 'coinvasity': 1, 'HsakaTrades': 1, 'parkeralewis': 1, 'cryptunez': 1, 'PeterLBrandt': 1, 'Bitit_Gift': 1, 'Travis_Kling': 1, 'Eljaboom': 1, 'NickSzabo4': 1, 'Bloqport': 1, 'bitcoinist': 1, 'deyonte_btc': 1, 'Lera_Mashigo': 1, 'PeterSchiff': 1, 'brandonlharris': 1, 'Rager': 1, 'coinpaprika': 1, 'cripto_vzla': 1, 'gutjahr': 1, 'BVBTC': 1, 'shadders333': 1, 'Delta_Exchange': 1, 'NgamoolaTweets': 1, '_unwriter': 1, 'connolly_dan': 1, 'Pixels4youcom': 1, 'OmoMamaCele': 1, 'spiralbtc': 1, 'MustacheTommy': 1, 'NorbertElekes': 1, 'coindealcom': 1, 'MessariCrypto': 1, 'TPSOperations': 1, 'Tradermayne': 1, 'nwoodfine': 1, 'justChinks': 1, 'bitpanda': 1, 'MichellePhan': 1, 'ColeGarnerXBT': 1, 'IPGaming_YT': 1, 'boaserichard': 1, 'zackvoell': 1, 'KennethBosak': 1, 'CryptoTimes_mag': 1, 'BTSEcom': 1, 'trylolli': 1, 'ademolaarr': 1, 'nejc_kodric': 1, 'Btc_grinder': 1, 'SmileyGnome': 1, 'TimDraper': 1, 'RelevantPeter': 1, 'ODELL': 1, 'btc_dakara': 1, 'BarrySilbert': 1, 'whale_alert': 1, 'glassnode': 1, 'theRealKiyosaki': 1, 'kucoincom': 1, 'KameronBennett': 1, '1CrypticPoet': 1, 'jk_rowling': 1, 'Kristian_Kho': 1, 'PrestonPysh': 1, 'MartyBent': 1, 'HODLBitty': 1, 'Schuldensuehner': 1, 'scottsantens': 1, 'Just2Bueno': 1, 'LilMoonLambo': 1, 'zelaapay': 1, 'CryptoR0ller': 1, 'BleacherReport': 1, 'ShamsCharania': 1, 'McClellanOsc': 1, 'SDinwiddie_25': 1, 'girlgone_crypto': 1, 'Dogetoshi': 1, 'LinaSeiche': 1, 'DavidNage': 1, 'mhluongo': 1, 'matthuang': 1, 'gladstein': 1, 'benmezrich': 1, 'darlingtonreal1': 1, 'AsktoMandrake': 1, 'LucasNuzzi': 1, 'sharkybit': 1, 'nanillionaire': 1, 'Ripple': 1, 'exodus_io': 1, 'novogratz': 1, 'SquawkCNBC': 1, 'paulvigna': 1, 'missteencrypto': 1, 'ChangeNOW_io': 1, 'ArcaChemist': 1, 'f2pool_official': 1, 'BitMEXResearch': 1, 'BitcoinMagazi ...

# %%
personas = pd.read_csv("Personalidades_Usuarios.csv", encoding = "ISO-8859-1")

# %%
len(personas)
# Out:
# 500

# %%
usuarios_cadastrados = []
for i in personas["Usuario"]:
    try:
        user__ = i.replace(" ","")
        usuarios_cadastrados.append(user__)
    except:
        a = 0

# %%
len(usuarios_cadastrados)
# Out:
# 146

# %%
#Data_Frame_Personality
datasource1 = pd.read_csv("DataFrame_Personalidades_kaggle.csv")

# %%
contador = 0
import nltk
import re
from sklearn.feature_extraction.text import TfidfVectorizer

for i in Usuarios:
    contador += 1
    str_ = Usuarios[i]
    user = i
    print(user)
# Out:
# APompliano
# CoinCornerDanny
# AltcoinDailyio
# nanogamesio
# cz_binance
# faveladoinvest
# DexiveExchange
# river
# GoingParabolic
# CashApp
# Bitsahara
# 100trillionUSD
# InstaSwap_io
# rogerkver
# tyler
# jack
# milessuter
# alistairmilne
# CoinDesk
# Bitcoin
# jchatterleyCNN
# MsHodl
# EduardoGavotti
# naval
# cryptocom
# SatoshiLite
# DTAPCAP
# PetroDivisa
# realMatrixport
# EshaanMenon
# satomichan0626
# PixbyToken
# Suheb__
# Cryptoking
# Cointelegraph
# justinsuntron
# CaitlinLong_
# DoveyWan
# ErikVoorhees
# charliebilello
# CNBCFastMoney
# danheld
# BithumbGlobal
# marcopologlobal
# cobie
# CryptoBull
# hodlonaut
# levijawn
# NexusOfficial
# TuurDemeester
# metaeconomia1
# MaxieRyan
# nwankwoesq
# Crypto_emrgency
# lopp
# AtomicWallet
# CryptoAdventure
# aantonop
# jchervinsky
# rektcapital
# woonomic
# crypto_birb
# TheMoonCarl
# cryptoshion
# DraxFTW_
# CryptoHayes
# Excellion
# btc
# Rhythmtrader
# nvk
# scottmelker
# WhalePanda
# crypto
# bgarlinghouse
# lightning
# bensemchee
# ftx_app
# sosjorginho
# juanrallo
# crypt0snews
# skwp
# BitShills
# binance
# bradmillscan
# nlw
# AngeloBTC
# DigitalAssets
# ALISON_airlines
# JoshRoomsburg
# nandszffc
# NostalgiaFlu
# jefimzao
# realsurgesolar
# fundstrat
# officialmcafee
# ANI
# RaoulGMI
# bitcoin_clara
# LinkupFr
# Xentagz
# blingfiapp
# AlyseKilleen
# coinvasity
# HsakaTrades
# parkeralewis
# cryptunez
# PeterLBrandt
# Bitit_Gift
# Travis_Kling
# Eljaboom
# NickSzabo4
# Bloqport
# bitcoinist
# deyonte_btc
# Lera_Mashigo
# PeterSchiff
# brandonlharris
# Rager
# coinpaprika
# cripto_vzla
# gutjahr
# BVBTC
# shadders333
# Delta_Exchange
# NgamoolaTweets
# _unwriter
# connolly_dan
# Pixels4youcom
# OmoMamaCele
# spiralbtc
# MustacheTommy
# NorbertElekes
# coindealcom
# MessariCrypto
# TPSOperations
# Tradermayne
# nwoodfine
# justChinks
# bitpanda
# MichellePhan
# ColeGarnerXBT
# IPGaming_YT
# boaserichard
# zackvoell
# KennethBosak
# CryptoTimes_mag
# pembertonrob
# amtvmedia
# thesahilsays
# Bitribeofficial
# IndiaAboriginal
# IvanOnTech
# indepreserve
# kerooke
# BitcoinBF
# IOHK_Charles
# coryklippsten
# Melt_Dem
# cameron
# GeoffLewisOrg
# GiveAndStake
# HuobiGlobal
# MMCrypto
# Breedlove22
# erikfinman
# BlvckDotun
# clarkmoody
# ScottLEOWarrior
# TheCryptoLark
# qtkyoo
# jimmysong
# BitcoinIsSaving
# BTSEcom
# trylolli
# ademolaarr
# nejc_kodric
# Btc_grinder
# SmileyGnome
# TimDraper
# RelevantPeter
# ODELL
# btc_dakara
# BarrySilbert
# whale_alert
# glassnode
# theRealKiyosaki
# kucoincom
# KameronBennett
# 1CrypticPoet
# jk_rowling
# Kristian_Kho
# PrestonPysh
# MartyBent
# HODLBitty
# Schuldensuehner
# scottsantens
# Just2Bueno
# LilMoonLambo
# zelaapay
# CryptoR0ller
# BleacherReport
# ShamsCharania
# McClellanOsc
# SDinwiddie_25
# girlgone_crypto
# Dogetoshi
# LinaSeiche
# DavidNage
# mhluongo
# matthuang
# gladstein
# benmezrich
# darlingtonreal1
# AsktoMandrake
# LucasNuzzi
# sharkybit
# nanillionaire
# Ripple
# exodus_io
# novogratz
# SquawkCNBC
# paulvigna
# missteencrypto
# ChangeNOW_io
# ArcaChemist
# f2pool_official
# BitMEXResearch
# BitcoinMagazine
# DGBAT_Official
# TanukiBTC
# feathercoin2013
# CryptoCronkite
# real_vijay
# AcervoCharts
# CountDankulaTV
# hibeekay_lee
# Cryptanzee
# Nouriel
# fiatleak
# DigitalLawrence
# purchasable
# coinbase
# galaxyBTC
# MattSenter
# alexadelman
# RosaRyyti
# BitcoinStimulus
# Coinkolik
# MoneyMan
# Ealvarezfight
# AlokVasudev
# prestonjbyrne
# BitcoinBrains
# VisionCryptoApp
# sthenc
# TeufeurSoff
# dan_pantera
# eTalentMoney
# Cele__Audu
# ally_praiz
# JuanPdeMungia
# ericnode
# BitcoinMemeHub
# bitcoin_brown
# yassineARK
# EmperorBTC
# CPSeduction
# ihatecodee
# JamesGRickards
# callmethebear
# Jidetum
# TheProleStar
# blockchainchick
# adam3us
# ForbesCrypto
# ToneVays
# mdotbit
# krakenfx
# LocalCryptosES
# JosephTodaro_
# Benaskren
# 0xElle
# Dehkunle
# BobLoukas
# stakecube
# Your_Girl_Mo
# robustus
# GibsoonCorp
# fintechfrank
# chainlink
# SHNDcoin
# gaborgurbacs
# MikeEMars
# MatiGreenspan
# juthica
# PARABOLIT
# whalepool
# HuobiWallet
# BitcoinLixin
# BTCsessions
# SterlingWitzke
# buycoins
# SwanBitcoin
# ercwl
# MarkYusko
# RD_btc
# KRMA_0
# TokenPocket_TP
# ALymphsLife
# CryptoHitmann
# balajis
# solana
# MrSurfvivor
# Taour_
# jackmallers
# TeoGarciaEgea
# Nakamoto_BTC
# saifedean
# Lone_wanderer8
# Evit_cani
# TaviCosta
# IamBitmannn
# DHannum8
# Vis_in_numeris
# AmoreLoveAmor
# truechaingroup
# paxful_India
# koinprocom
# VitalikButerin
# AcalaNetwork
# FTREFORMED
# RussellOkung
# play2earncrypto
# MaziSamson
# SanojaReinaldo
# gator_bitcoin
# AdewaleOTunde
# ojeohis_
# Auntyadaa
# caprioleio
# nnaji_kate
# pascalboyart
# christhebigmac
# mountain_goats
# The_Oracal
# BTChap
# CircuitSociety
# Codiox
# CRYPTOFIED1
# abhizz16
# UniPowerGroup
# davidgokhshtein
# CryptoBullRon
# CryptoFortuneT2
# billburr
# erigganewmoney
# CoinCornerMatt
# kittyDCT19
# PundiXLabs
# psycoGAW
# BitrueOfficial
# FIatEarthMaps
# Vetologism
# blockandchain
# MalwareTechBlog
# btc_for_etc2021
# blKKstar
# UpholdInc
# CryptoChihiro
# ericgarland
# meupedebitcoin
# WazirXIndia
# Cryptogirlczai
# FUBTC
# ToXsiK
# thejohalfiles
# real_mercyeke
# maxkeiser
# CryptoStewiee
# notgrubles
# LindaKebbab
# bitcoinzay
# Bquittem
# CryptoZeinab
# nntaleb
# yotanlim
# CoryTV
# wazapepe
# Base58Check
# WhoKM
# koeda201515
# tatianakoffman
# coinpicksjapan
# mcnicollme
# satsdrop
# gavinandresen
# paypdmofficial
# TheDaoMaker
# katecrypto0
# TheWorldsAMine
# bitcoinographic
# HRF
# TheCelsian
# pushpendrakum
# nikzh
# realmaxkeiser
# CryptoCred
# SecretsOfCrypto
# callummarkie
# pwuille
# bitcoincoreorg
# ArgosCrypto
# FinPlanKaluAja1
# BW
# LynAldenContact
# volker_btc
# MaatlaKgasa
# friedberg
# GeorgeAnthonyO1
# SchenolS
# spectatorindex
# BuyingEveryDip
# DocumentingBTC
# _benkaufman
# saylor
# ayewaken
# WhaleChart
# MacguyverTech01
# socialbrice_
# zerohedge
# CryptoCapo_
# mistcop
# Maison1472
# realfrankwilder
# QNTMami
# BitfuryGeorge
# SInow
# Crypto_Potato
# BugrraOzturk
# bitstein
# nypost
# benthecarman
# Pelabur_Bijak
# macguyvermedia
# SwingbyProtocol
# TecraSpace
# Crypt0kyuubi
# GiveAwayHost
# QuintenFrancois
# rivatez
# BigCoinCrypto
# ippatel
# KSI
# wolfipali
# rezarazali
# PeterMcCormack
# TrVon
# masmasjawabgt
# scoinaldo
# CryptoSlimer
# arambarnett
# CarlosMaslaton
# CharlieShrem
# AmitShah
# pete_rizzo_
# SpencerKSchiff
# imBagsy
# bainesy4886
# mishalederman
# iamjosephyoung
# stoolpresidente
# VersusBtc
# FranceCryptos
# bigbunnycrypto
# EllieFrost
# PrimeXBT
# levie
# FrancisSuarez
# RookieXBT
# loopooYT
# EdVanDerWalt
# Verox_AICrypto
# eqonex
# BCBacker
# sof1azara03
# Timcast
# luiscarrillo66
# DrBitcoinMD
# satyakumar_y
# FEhrsam
# n3ocortex
# EconguyRosie
# XFII_Tech
# AWice
# DavidHundeyin
# HerroCrypto
# PJanuel
# fastswapdex
# PPathole
# elonmusk
# liadiVIII
# WolfBritton
# Crypto_Daily
# WendySiegelman
# WClementeIII
# billcashidy
# theestallion
# dypfinance
# outfitter_the
# mowaseife
# KingPandah
# Bluzezs
# JaValeMcGee
# JustMiningFr
# gate_io
# Jotteee
# DONJAZZY
# Stocktrader
# yurumazu
# 3LAU
# kashhill
# VzlaUfo
# foloflow_
# cex_io
# obyn_designs
# therealjuicyj
# twobitidiot
# Casey
# Snowden
# Dostlar_Hanesi
# le_gorafi
# eha_news
# business
# coinflip
# blockchain
# DegenDefiYT
# ZubyMusic
# Bitstamp
# WeBlockEnglish
# thedailybeast
# StoneAtwine
# ShaanVP
# OpIndia_in
# kurtwuckertjr
# itsprettyjamie
# c_aashish
# BJP4India
# cakedefi
# PettyWap0
# Eric_BIGfund
# smritiirani
# narendramodi
# PiyushGoyal
# JPNadda
# StealthPay
# dmlayt
# xD4rKs0u1x
# CalifaPoppy
# freddier
# viniciussexto
# dbsbank
# Bybit_Official
# Square
# cryptowarriorr
# BetllerOfficial
# coinbeastmedia
# Trezor
# KennethDredd
# KittyCoinGlobal
# nfergus
# stephanlivera
# NeerajKA
# cryptonary
# ReutersBiz
# JacobCanfield
# AynRandPaulRyan
# parabolictrav
# wealth
# BitCokedotcom
# BlockFi
# CoinbaseExch
# AnChainAI
# Tarmexio
# webounty_io
# Tegadeyforyou
# CryptoGodJohn
# ConflictsW
# GoGalaGames
# BlockRating
# 1MillionTokens
# lawmaster
# SamouraiWallet
# LooneyTunes
# longtunman
# LuchoPoletti
# CryptoTownEU
# kaparthi_j
# SimonDixonTwitt
# BohrBitcoin
# HukAleksandra
# theasiwaju247
# cryptopigmedia
# byeagle37
# BigMan_Xander
# black_bhoy_
# Ibrahim_Bello_
# sametoolz
# Sweepsgg
# jbarro
# axios
# BTC_Archive
# biancoresearch
# kacperski719
# gonnassau
# NextWaveEFT
# cissan_9984
# Life_After_18
# ki_young_ju
# Psolemn
# Leishman
# mainakTdas
# NischalShetty
# 0xglitch_
# ObongRoviel
# PratikDunya
# bascule
# JonErlichman
# TansuYegen
# ck_SNARKs
# MrktMeditations
# Davincij15
# iamZatoshi
# mskvsk
# patriottakes
# bsvscreen
# aubreystrobel
# J0hnnyXm4s
# CobraBitcoin
# patonet
# haskologlu
# Lukewearechange
# GRDecter
# Fxhedgers
# PFTCommenter
# davidgerard
# abdullahciftcib
# GameofCoins5
# SFHShoops
# Scaramucci
# vhic_tore
# DzambhalaHODL
# JamesTodaroMD
# Irunnia_
# taopiphop
# GemGamenft
# Miz__maheeda
# LibertyRPF
# lexfridman
# zhusu
# DCLBlogger
# MrOdanz
# tehMoonwalkeR
# PlateauGirll
# satoshibaggins
# BradMichelson
# DrTONYAGBATOR
# WSBChairman
# LibertyBlitz
# CryptoNewsYes
# AllisonReichel
# tesla_raj
# trending_medic
# AtifRMian
# khannib
# fluffypony
# ihsansenocak
# latokens
# MikeProposes
# mir_btc
# whitenigerian
# DeItaone
# TonySparkOG
# CNBC
# GregHathorn
# CryptoWhalebot
# fishxbt
# bud_crypto
# locodeschamps
# channelstv
# altugozturk
# realMeetKevin
# dougboneparth
# Jackvladamir
# CryptoHornHairs
# BloombergTV
# TheStalwart
# IStandWithPYO
# crypto_rand
# tonjukuk
# YieldApp
# saylordotorg
# CryptoWhale
# carlquintanilla
# azeaybalam
# fatmadiyin
# pookleblinky
# qikipedia
# itsALLrisky
# clairlemon
# TheBubbleBubble
# JeffBooth
# trevorjonesart
# souljaboy
# AriDavidPaul
# AnitaPosch
# yemencankan
# MarketWatch
# beatsgordy
# thepaulosophy
# hasufl
# ValaAfshar
# jackdanger
# TeminatorTrader
# skyler_fs
# bokujyuumai
# FinancialGory
# saskilla
# KoichiTsunoda
# peris_ja
# Mediavenir
# foosgonewild
# RyanRotolo
# jordanbpeterson
# DanielaCambone
# bitcoinclips
# MorningBrew
# WayneVaughan
# CryptoTrendsz
# KimDotcom
# genesimmons
# EricBalchunas
# TheIrishCrypto
# TurnerNovak
# MattWallace888
# goto_nikkei
# noshitcoins
# EricHolthaus
# lindsaylohan
# renoomokri
# renprotocol
# marcvanderchijs
# BadgerDAO
# omg_keynes
# machineiv
# DreadBong0
# BrainHarrington
# moderate_ustaz
# 997_Carrera
# BrightJaye
# AfricaFactsZone
# Enitan_sam
# dergigi
# tradingview
# DogecoinRise
# shanstory
# RafaelH117
# dilutionproof
# Joeingram1
# krugermacro
# themotleyfool
# Izzy_Lu2xx
# ZevMintz
# HappyShillmore
# nic__carter
# LayahHeilpern
# Timccopeland
# shoegalnyc
# yocchan60
# KatieTheRussian
# dannydiekroeger
# abdulalimuk
# RobinhoodApp
# deech
# JoannaBlackhart
# C_Angermayer
# muneeb
# anilsaidso
# KinseyGrant
# metroadelantado
# Andrew_J_Howard
# iamkoshiek
# CryptKeeperBTC
# markets
# riki_sakamoto
# LEON9750
# CathieDWood
# news_of_bsc
# MadamClinton
# CryptoMichNL
# llamasoft_ox
# StarkWareLtd
# umbrel
# digitalassetbuy
# MartiniGuyYT
# Nicholas_Merten
# cryptowat_ch
# plan_marcus
# LukeGromen
# vogon
# satsie
# QueTesoro
# CoinCornerMolly
# elliotrades
# Cryptobabushka
# AsennaWealth
# jamesviggy
# DeFiHulk
# KetanJ0
# BitcoinCameron
# FirstSquawk
# Dogecoinrich
# TCR_news_
# CNN
# JohnOdetteMD
# philthatremains
# ohlalamilala
# SantiDiPaolo
# ivancarrino
# dimacgarcia
# ComplexMusic
# Complex
# trader_ferg
# DefiantNews
# YellowBlock_io
# jakepaul
# RARohde
# BitPay
# DiepSanh
# LatveriasDoom
# TechCrunch
# DeepFuckingDefi
# GrantCardone
# javiernavia
# YoungCryptoPM
# Sonjoe_Kutuh
# EmmaRincon
# knutsvanholm
# BitcoinSapiens
# MariaPesce_
# BITVOLT7
# Techconcatalina
# seyitaylor
# TosinOlugbenga
# Cokedupoptions
# bigd3bs
# RampCapitalLLC
# Reuters
# EricRWeinstein
# _bitcoiner
# hiropi_fx
# VentureCoinist
# thecryptomonk
# decryptmedia
# MacroScope17
# sk_cadi
# HaileyLennonBTC
# DeadlineDayLive
# EmekaNwaGuy
# JamesFourM
# RyanWatkins_
# RealRBHJr
# CoinPaymentsNET
# NobotoGen
# chrismelberger
# onybose
# BitsonicGlobal
# Earth_Jennie
# OlamideQuadri4
# Andrewstotle
# willcole
# ipvkyte
# smdiehl
# SalesNotepad
# JacobOracle
# surayaror
# dril
# lisekimhorton
# robertcaruso
# JuliaDavisNews
# RedTRaccoon
# MingGao26
# Crypto_Fridays
# denverbitcoin
# NickKristof
# Mpolymer
# dobuybitcoin
# WSJ
# klever_io
# RealSpikeCohen
# DrDenaGrayson
# splendidland
# YourAnonCentral
# SethAbramson
# brianschatz
# FrankFigliuzzi1
# MrShawnRogers
# hodloncomrades
# sparrowmedia
# donwinslow
# jjmacnab
# Y2K_mindset
# Quicktake
# ABC7
# AKiyoshi0605
# LizBitcoin
# camilladelucas
# tim_bitcoin
# Ujbaby12
# IGN
# DeribitExchange
# dealsandcoins
# Rothbard1776
# btcdarwinist
# PrisonPlanet
# alispagnola
# ClayTravis
# ParikPatelCFA
# MRKR
# PatrickAdemo
# najihahshahrel
# Erikcason
# ashgoblue
# nytimes
# LisaKramer
# ameero1
# laevitas1
# gustavo_srcc
# gyaigyimii
# alamin_ghost
# Buffettsbroker
# DaveInTheCut_
# btc_quotes
# litcapital
# izzy9821
# canalCCore2
# HTDcris
# Mochievous
# Kingston_eze
# kusssman
# logos_id
# eliasimos
# MaximilianXCIX
# ShutupRuss
# lemasabachthani
# billbarhydt
# murdabeatz
# didikins4life
# JoelKatz
# primalpoly
# KotaTheFriend
# PrasagaOfficial
# michaelbatnick
# IIICapital
# asemota
# luis_villegasr
# stacyherbert
# ICOffender
# btc_racing
# CryptSpecialist
# ThaGuru_
# aiautosng
# GbengaGOLD
# kigyo_seiko
# twetchapp
# saxena_puru
# Jestopher_BTC
# KelvinOssai
# ChainlenkMyses
# bfmbusiness
# JasonYanowitz
# BTC_JackSparrow
# techwithcatalin
# GaryLeland
# WavesMediaNG
# Zlatan_Ibile
# Nerd_Stack
# paoloardoino
# VictoryAlex4
# Uncle_sarm
# FIREBTC1
# Xenos_Giveaway
# KatusaResearch
# Naija_PR
# russdiemon
# greentoepalacio
# iaboyeji
# JE_dna
# _EmpressSara
# tobias31
# XaviercMiller
# zzabbits
# swoph
# KoroushAK
# AmgMedikal
# breakchainsmag
# ecoinometrics
# TheGod0fThunder
# CoinMarketCap
# IwanRabbinstein
# No_Limits060
# obi
# ReutersTech
# Grayscale
# 0liminati
# tracyalloway
# AlexSaundersAU
# gregory_raymond
# garciabanchs
# RCachanosky
# savannahbrown
# ajv
# Diditaihuttu
# cakman4
# Blockstream
# Froste
# danorlovsky7
# MKBHD
# Bitvarna
# Valeezy
# iamchrisani
# dmuthuk
# dlacalle_IA
# Morris_Monye
# HSouthwellFE
# ThomasEWoods
# thenoelmiller
# typerbole
# chamath
# the_ironsheik
# austin_rief
# dammie_remix
# noahkaufmanmd
# oloye__
# jsblokland
# Burmese_Tyga_
# HigherManas
# BBCWorld
# orangebook_
# StatsBTC
# ChefGruel
# Croesus_BTC
# tuihane_
# yaneuraou
# technology
# avcemilcicek
# MoneyKripto
# cryptoBaddiee
# crypto_bitlord7
# BP_VotingTeam
# ChipotleTweets
# TylerSCrypto
# Bitboy_Crypto
# JamesB_65
# flyingbtsarmy
# TeletubbiesHQ
# Hugh_Son
# dentcoin
# Bang_Garr
# heyjenbartel
# JohnStossel
# Coinicarus
# chadsgx
# ashwsbreal
# milyonerzihin
# lelibertee
# TakaSNSmarke
# verge
# annairrera
# BTCAaron
# Blockworks_
# purengom
# OgbeniDipo
# taylanyildiz
# Forbes
# MustaphaOlatu19
# ChrisJBakke
# MemesZil
# RealJohnDough
# bitcoinmom
# CryptOrenda
# BullishHem
# EdanYago
# mazi_manulu
# wallstwolverine
# Mojoaf
# neilhimself
# fakedannydevito
# nanutria
# yazarmuratakan
# hvgoenka
# CynthiaMLummis
# Pladizow
# mcuban
# Chemicalboyy
# web
# kevinolearytv
# jemimajoanna
# draecomino
# ChainLinkGod
# ManySwap
# wsbmod
# TagadoBTC
# CryptoDavid_
# MusaNV18
# CryptoWizardd
# yulesa
# brian_armstrong
# Joe_Saz
# LuckyLukeCrypto
# shakepay
# airdropinspect
# cryptovenizo
# EconomistaFlait
# shl
# JaymeKnyx
# cnni
# launchzoneann
# Baklava_Mami
# MackAttackXRP
# argueta____
# Crypto_Mags
# UncleRickT
# PeterDiamandis
# randymeeks
# TimmerFidelity
# Replit
# xagreat
# thebitcoinrabbi
# GamerSupps
# AirdropStario
# chakaneld
# DavosCryptos
# ZevShalev
# MrHodl
# PKuipersMunneke
# MrFreshTime
# LilyKnightShow
# jimcramer
# rah04444
# BTCMinstrel
# mleonardi247
# JunkoSu22993224
# SeniormanOA
# BookofNick
# Liat_RO
# ByzGeneral
# beeple
# BitcoinMaxiHodl
# _morapr
# DocumentEther
# JohnPompliano
# newscientist
# 808TA_
# DigitalDoji
# catgraffam
# steve_hanke
# Edopikin75
# Investingcom
# LockedInTeam
# OrdinaryGamers
# Luchap2BTC
# AirdropDet
# JeffyMeyer
# WIZARDTOSHI
# TxGamerChick
# spence_btc
# IoniAppelberg
# JohnEDeaton1
# KopeFinance
# ArbitrageOps
# jaygould
# bstategames
# wikileaks
# CryptoQueen7777
# DickTra52041861
# onedracokeem
# BitBitCrypto
# ryadam_
# kashthefuturist
# macaronswap
# nixonfoundation
# Independent
# VforVechain
# poli_1312
# eketiette
# dumbricardo
# Jayecane
# s_alderoty
# cryptoWZRD_
# sentosumosaba
# robxrp1
# bycoinhunter
# _Mbalivalentine
# greg16676935420
# adam_tooze
# jackiefriman_
# iamdevloper
# adon_network
# Tebogo_Pta_
# UTRUST
# nekadmorello
# kyle_chasse
# MrColionNoir
# _MattHill_
# lacrymmosa
# MrRomyRome
# zariat
# RavindraGautam_
# watchingstar92
# austerity_sucks
# CryptoUB
# dedikodubjk
# CryptoRank_io
# ifriend05
# BitMartExchange
# ramit
# Mrbankstips
# kolpacinofacts
# CryptoHodlhodl
# CHAIRFORCE_BTC
# himantabiswa
# Quophieparadise
# bitcoinclubmt
# XRPcryptowolf
# intocryptoverse
# BitMEX
# BillyM2k
# culkin22
# Geronimuslll
# nikichain
# RyanSAdams
# NakamotoTsunami
# Crypto_dealer1
# ShaneLunde
# AltCryptoGems
# leyawn
# jayberjay
# flglmn
# chowcollection
# GoldTelegraph_
# FBIWFO
# filbfilb
# NUgarislucu
# Crystamped
# FranckLeroy_
# cryptoxchris
# alpacasw
# baylorlandry
# NewYorker
# rhinosoros
# EpsilonTheory
# santiagoroel
# __nate__
# memenist_
# stevejang
# KimletGordon
# reb0rn13
# samliogluayseni
# milkteus
# LesliePicker
# TheCryptoCandy
# jezhumble
# WisdenIndia
# Mirchi9
# CricCrazyJohns
# garyblack00
# Eig_Banphot
# DanielleMoinet
# NorthmanTrader
# GraffitiKINGS
# CryptoBoyNFT
# NatureCrypto
# billmckibben
# dharmesh
# JoePompliano
# CNBCWEX
# btcale
# safemoon
# cryptokahin
# Hypafly1
# Sheldon_Sniper
# MadDogecoins
# edugaresp
# bethanyhamilton
# BitcoinBirch
# bricepromos
# Theo_mwangi
# dr_Q8i_
# GregAbbott_TX
# btc_FX
# TUnderground_
# mifixit
# Seetee_io
# zGuz
# DropoutDepot
# TheBitcoinConf
# clown_depot
# LauncherNft
# btc_magazin
# Axel_bitblaze69
# Nataliekitro
# chemicalbrodar
# ladymarketok
# RedPandaMining
# tokcem
# SayarBilgi01
# Remmzor__
# emilio_vicent
# Dennis_Porter_
# Dhruvbs
# ayomiajiboye_
# GalaxyCoin_Fi
# ZeroHedge_
# SafeBull1
# berilinni
# cryptomanran
# billmaher
# alejnwn
# DylanLeClair_
# legadaodamassa
# BitcoinTech5
# ShibInformer
# ConsortiumZ_
# jonatack
# WuBlockchain
# LuckyMahloane
# PrimordialAA
# EdoEdikson
# JRNYcrypto
# arcanebear
# rinusveekay
# MarkusTurm
# Pinboard
# saquon
# JessicaVaugn
# FractalEncrypt
# JSCCapital
# CoinPayU
# royzkingin
# HODL_sworth
# pwittaya
# VICE_ID
# CroissantEth
# BeatinTheBookie
# haydenzadams
# adrianceitor_
# Poloniex
# Bitcoinsensus
# DaanCrypto
# Deyonte_btc_
# Vizzy_rayven
# coingecko
# crypto_bobby
# janetmachuka_
# phil_geiger
# VascainoOficial
# romanmartinezc
# Sakebomb
# QuidaxGlobal
# tomwarren
# ThaRealBello
# im_chandresh
# AbuHayaaa
# ObiWanKenoBit
# MotiveNFT
# john_j_brown
# nosleepjon
# ProfDemirtas
# BurencyOfficial
# TheRealTahinis
# handokotjung
# mecee
# sexy_diana1
# SSejderha
# funnydafidi
# AngeL_QueeN815
# jonwu_
# mohitmamoria
# tensaibankai
# ShaunWitriol
# NeilJacobs
# hodooi
# tsukibito_money
# andrewrsorkin
# songbird_britt
# alifarhat79
# Moonchaser2020
# _amanda_fab
# TheBlock__
# coinbureau
# mcclure111
# esneisser
# RelevantElon
# 1MarkMoss
# jakeeswoodhouse
# BTCTN
# CryptoPanth
# iSlimfit
# QwQiao
# mhiramat
# YahooFinance
# JiangZhuoer
# Jamestown_ng
# KpopToken
# Bigmozel
# WyckoffOnCrypto
# NathanJRobinson
# harryhurst
# Ninjascalp
# TrungTPhan
# yungNleveraged
# stillgray
# VectorMoon_BSC
# Ionut991
# Donjuliozz
# AJA_Cortes
# marcelorubens
# om_crypto
# WholeMarsBlog
# Mounia_NL
# lightcrypto
# glassnodealerts
# georg_kofler
# tomui_bitcoin
# HuertDeAuteuil
# ByYourLogic
# hakkiocal
# ZssBecker
# Coachkcrypto
# Captain_Kole1
# Hecmarch
# hecoswapdefi
# Slickedon_
# cryptonator1337
# RichardHeartWin
# corndalorian
# JudgeGregIsLaw
# MarleyBitcoin
# pulte
# SteveMartinToGo
# RobertKorhonen
# kaisercrypto
# FerghaneA
# SquawkStreet
# cmsintern
# ICOAnnouncement
# cryptowhitewalk
# joeykrug
# LinksSonny
# ImNotTheWolf
# JeffKirdeikis
# 360_trader
# BCAppelbaum
# jowyang
# paulkrugman
# damskotrades
# giacomozucco
# hitbtc
# therationalroot
# DiamondTooflex
# Brunozor
# mrnguyen007
# sendagurah
# JordanSchachtel
# 3DNuts
# casichequeado
# SBF_FTX
# wintonARK
# Vivek4real_
# _pbandjeffy
# ribsalrio
# aroliveros
# SGBarbour
# ShardiB2
# FarooqAhmedX
# escachadisima
# BITCOIN_AL_DIA
# DBATTAGLIAYtube
# emergent_btc
# BrendanBlumer
# bosveryavrum
# Mrfunny___
# adamsamson
# TradingduCoin
# AlamedaTrabucco
# eri1591
# VisualCap
# matvelloso
# FossGregfoss
# luide
# Mashinsky
# BeegSmokey
# axelgxmxnxz
# muhammedalisma
# PowerLunch
# Hbomberguy
# MixtaOlamilekan
# shamanpr
# SheldonEvans
# raypaxful
# jessicahodlr
# 0xBrk3
# 16doge
# OracleFastMoney
# WhatBitcoinDid
# LordFusitua
# ConorOkus
# ElTrompudo2022
# MissDemas_
# RektProof
# ChainBytes
# carlitosrejala
# beniaminmincu
# OMGno2trump
# Masferrari_
# CryptoTodayNet
# BexplusExchange
# OJMATINEE
# osayich
# Msupa_A
# _elfaro_
# SNietoCastillo
# rjames_BTC
# CryptonautsShow
# misconfig_exe
# napocornejo
# tatymarroco
# bulllmarketcoin
# ThinkingCrypto1
# alrawenet
# Bitcoinbeach
# jmcorgan
# ElectionWiz
# cryptogems555
# JackPosobiec
# MatthewTyrmand
# roquemocan
# YourAnonNews
# easegura
# nayibbukele
# KenzieSigalos
# SiberetSiberet
# alfredmalmros
# FinancePomo
# olya_borderless
# Lawrenciumtoken
# DebirexPR
# Oladapomikky1
# Mister100x
# AHT_YssY
# projectmano
# FilanLaw
# cvpayne
# elsalvador
# CoinvoteCC
# coin_post
# mikemcglone11
# brgsjks
# Beiioso
# MattBinder
# MobilePunch
# nicolasburtey
# GazetteNGR
# Altcoinbuzzio
# just_a_happycat
# BardaVuran
# TheDailyShow
# JJcycles
# _MoisesRivera_
# bitentrepreneur
# ST_World
# hampus_s
# AaronvanW
# alphaN1
# Definomics_
# based_fyodor
# 42RaptorJesus42
# angel_funsized
# HodlrDotRocks
# empatik
# DigitalChamber
# enrique_anayasv
# fvdemocratie
# VRA1DOLLAR
# dldasilvarosa
# bryan_a_cheung
# JoshMandelOhio
# SergeyNazarov
# dominguezrafa47
# allan_barrera
# MustafaYilham
# joseluismr1
# m__btc
# OfficialTravlad
# PositiveCrypto
# WalterAlemanSV
# brad_polumbo
# WORD_NEWSS
# CitizenBitcoin
# WarrenDavidson
# saratu
# Raph_Bloch
# Telemundo
# BryanGuevara17
# troytrade
# mikejcasey
# colbertlateshow
# jmoBTCity
# atrupar
# ThirstyDoge
# oliaubin
# FrogeFi
# frogefinance1
# michaelmalice
# csuwildcat
# btcdisciple
# SenWarren
# sirbullycrypto
# TimJDillon
# Loot_Back
# ParisHilton
# cryptograffiti
# eliass_nomas
# antoasb
# GabbiValencia
# Frances_Coppola
# Santogalactico
# FXsugusineru
# sulenayala
# dondekojo
# 2seokily
# re_basado
# mutatrum
# TheObjective_es
# servicehubb_ng
# _SirWilliam_
# Phoenix_Ash3s
# Symply_Tacha
# AnabelBelloso
# AFP
# Bitcoin_Wifey
# Obacruze
# AlertaNews24
# Capitalnvest
# laderechadiario
# CryptooIndia
# AsambleaSV
# rodrigoayalasv
# lalittlelya
# DaniaGonzalz
# raudaz_
# handsoffmysats
# RMac18
# udiWertheimer
# scwolf5
# CakeSchon
# Chelita_NI
# cuellarSV
# hrkbenowen
# MattSpoke
# Recasta
# attorneyjeremy1
# DinaArguetasv
# markjeffrey
# LeonorSelva
# DogeBitcoin_bsc
# Okcoin
# orlandoalarcia
# ECastroES
# CryptosR_Us
# aPerfect_System
# rkartagena
# IOHKMedia
# ChefManey
# CaleCrypto
# MIT_CSAIL
# CavedIsolation
# cryp2_
# markpeak
# hodlberry
# hodlKRYPTONITE
# BabelHodl
# jareun_2
# SecurityGuyPhil
# intangiblecoins
# gilson__marques
# Acyn
# DefenseBaron
# QTRResearch
# GeoffRBennett
# mxgxw_alpha
# alyshagives
# TronDao_ESP
# SaycheeseDGTL
# Andreas91211522
# MiguelAguileraR
# somaditya_eth
# txbit_io
# zibin
# coinstats
# ohmzeus
# deccache
# NewWorld_Order7
# sndbtc
# estendenciavzl
# bairesmario21
# RT_com
# redliveOfficial
# Justdoitalex
# HammerToe
# GlennMarFano1
# Eyaaaad
# celeste_brightt
# hodldeeznutz
# ericyakes
# F1XTHEM0NEY
# mikealfred
# XavsFutbol
# abetrade
# BenCaselin
# THE_BASED_CEO
# CryptoKongOG
# WhaleyEth
# theapexbt
# GuardBitcoin
# AKIRANSAL
# dogegod123
# dogeofficialceo
# WolfClub86
# MetaGorgonite
# laktzsuz
# woofBIGDAWG
# CryptoPoorBoy
# Loopifyyy
# PancakeSwap
# SafeMoonRich
# BustaRhymes
# Thecryptomist
# fw_slick
# ClaudiaAmbition
# maazi_ogbonnaya
# CryptoPunch5
# BabyBITC_bsc
# teen_executive
# BTC_LN
# TequilaPartyBsc
# enezozenreal
# hodlcryptoguys
# Arinzeudeh5
# DefiSportsCoin
# koryodynasty
# Luna_Finance
# BLACKAdidanca
# AAXExchange
# kjalee
# PsyJayCrypto
# METAPLAYio
# MyCrypto
# TheRealKeean
# chisaidoge
# TheGuySwann
# DefiApes
# penguinpromotes
# SebGouspillou
# isabelleboemeke
# CryptoKaleo
# dubyabee17
# thealexgalaxy
# hardmoneymag
# ARKInvest
# KenKingCastle1
# Casimiro
# BTC_urakawa
# Cenismo
# G_dogetoken
# Noah_HQ
# FTX_Official
# ProTheDoge
# DelRayMan
# emreaydin
# NateAlexNFT
# DeepikaBhardwaj
# CompBrosCrypto
# CryptoBoltx
# MasonTHFC_
# MASTERBTCLTC
# SpursyDave
# natbrunell
# ErinEMalone
# DailyAFC
# RolandStautz
# DailyCryptoGems
# CryptoGamer4591
# coinsniper_net
# MikeTyson
# esec76
# leehoole99
# BitcoinFear
# RealBishopKP
# _Checkmatey_
# coinscopecrypto
# ScottMinerd
# MyDogeAccount
# maskthedegen
# bitgertbrise
# btc_break
# MayorConger
# santimentfeed
# ThiagoResiste
# manotelli
# Jihoz_Axie
# Stupid_Eco
# BitcoinAssn
# H2xV7
# nice_mustard
# FlareNetworks
# JaviSiman
# EugenioChicas
# dippy_eth
# kriptosezerbtc
# Airdrop_Exp
# tedcruz
# Nyuuutokun1
# CryptoStuds
# ibepacheco
# paulg
# RicardoBSalinas
# JasonPLowery
# PostyXBT
# gametheorizing
# JoonasCrypto
# cryptoprakhar
# easyeight08
# LolliDeals
# XRP_Moonshots
# Finn_BTC
# Spizaetus_T
# KichiCoin
# devanwonders
# RewardHunters
# CEOAdam
# sunnydecree
# siamblockchain
# roguesocietynft
# sonalibasak
# Pelicans_tech
# boxmining
# malcomgomez
# Genius_Crypto_
# pontejornalismo
# ChaseHughesNBCS
# Kceoda
# TheBlueMatt
# BTCGandalf
# The_O_Show_
# ShortTheVix1
# DeTocqueville14
# pourteaux
# ryanpham92
# gegelsmr2
# ronnie_184
# OfflineExchange
# NikolayShkilev
# ThunderProtocol
# komochi4xamo
# LegitCryptAlert
# DanielleFong
# marcfriedrich7
# Pjbass1610
# wallstmemes
# DeFi_of_BSC
# TheCryptoDog
# baumplanning
# ladyincrypto
# SatoshiRipper
# AltcoinGordon
# allenf32
# Cooopahtroopa
# sassal0x
# ayewakencrypto
# ThePsychoBot
# DavidFBailey
# SenToomey
# ShireHODL
# camgeary
# Korsogyimi
# SlushFinance
# JohnWRichKid
# alexbosworth
# crypto_twilight
# davidlin_TV
# GemSantosCrypto
# OriginsReturnSC
# KarlSmithCFA
# delhichatter
# Crypto_QueenBit
# fxoldman0321
# JoseValdezSV
# Astrones2
# cryptofunksNFT1
# Perry_satoshi
# TechDev_52
# DogecoinCuban
# adrian__chamber
# TurkElit
# hrtlndbitcoin
# GilbertoEsc_
# Pentosh1
# adriha14
# eToro
# bloodgoodBTC
# pasindubro
# miguelmazzinni
# RTRcrypto
# AshNFT__
# BoredElonMusk
# Conexion_BTC
# GraffitiRadical
# AarikaRhodes
# bitharington
# LovecoinProject
# qntcap
# LiquoroseAfije_
# mxgxw_gamma
# thebearablebull
# CoinSwitchKuber
# zenithchain_co
# PlentyDeFi
# alamin_ys
# beaniemaxi
# yungbayker
# hmsnofun
# f_schaeffler
# ForeignPolicy
# flrfinance
# LilNasX
# finance_hipster
# ShudanXie
# bit2me
# xrp334
# cougarswap
# awrigh01
# XRP_OWL
# GMT_Token
# WOLEXZ_TRICKz
# dw_espanol
# VozdeAmerica
# prensagrafica
# Jacobogg
# waraujo64
# pdahlberg
# metzimartel
# MarketMoveAI
# King_Sibeko_
# Financialjuice1
# altugisler
# CTrade_official
# TrueAnonPod
# Immortalznft
# paxful
# ParamiProtocol
# Jaiyejejeomo
# Steam_Exchange
# ElPolitologoSv
# giftedhandsGHD
# AbdulkerimSma
# BitcoMineToken
# wiz
# CaptainsCryptos
# cryptomusclejoe
# MrGrandpaDoge
# peterktodd
# el_timoke
# KayahanKaraman
# rsg
# Alin_George88
# unatalandie
# ElSalvadorBTC_
# joseantonetti
# bsc_trader
# AmmousMD
# mommajessiec
# GravelInstitute
# MarcFalzon
# WendyRogersAZ
# QuitoArmado
# BTCSkye
# clinaliciaare
# Nebraskangooner
# Inconforme75
# MrTimothyAllen
# crypto_bearr
# SebSats
# tmcel
# Corinthians
# listocomics
# CarlosM25928655
# esmesol12
# BitcoinCarl_
# SamuelCryptoV
# SMiTHiE___
# djsbu
# Jairomartinez87
# ComunicacionSV
# BarachelElihus
# Baykus2022
# SantaT3chL4w
# gfrias
# LaRodriguezCJ
# ClaudiaOrtizSV
# yosoyCortez1
# joseantoniokast
# thamireshauch
# momochan_BTC
# ReyesMario25
# JohnnyWSol
# AlfaroDev
# ElMundoSV
# _jonasschnelli_
# Mejia28D
# bbands
# RTultimahora
# lacomunaresiste
# king_btc_xrp
# jameslavish
# MigueVaquerano
# victorpena84
# Leerzeit
# OscarMachon
# aproko_doctor
# JuanCallesMAS
# thecuriousdan2
# ReinyPonce
# DaddyskinsCSGO
# Bart_Mol
# aleanndra
# gregisenberg
# sophiamzaller
# LuisFe_Val
# metamantra
# elmundoes
# digicel_sv
# Somosngeles1
# fernandoacastr1
# TigoElSalvador
# iost_japan01
# DiarioLaGaceta
# TVMenvivo
# chivowallet
# kaswizofficial
# MilenaMayorga
# Forbes_CA
# JamieStuckert
# healthy_pockets
# mcmillen
# BigSeanHarris
# BABYDBILLION
# TurboXBT
# OrangePillWilly
# FXbitcoinETH
# JColagrossiNeto
# NinoconBarba
# marketing_btc
# Cryptolyst_
# AlexLielacher
# ScottAdamsSays
# CronistaOscar
# jswatz
# CryptoMoonWolf
# XiranJayZhao
# TJCobain
# noey0_0
# ReneMartinezPi1
# Bitcoin_ator
# _nnddaeng_
# GoldenRoots6
# KanoTheTruth
# ZinedHodl
# UCA_ES
# TheOnion
# wwwerkerkcom
# cryptokoray
# raw_avocado
# TrueCrypto28
# New100xGems
# tip_nz
# cburniske
# YoadaStakepool
# seedphrase
# LaBonitaSV1
# hectorsilva
# WillieVentura_
# Teleprensa33
# criptobastardo
# RevistaFactum
# romangressier
# jessethechef
# robindaygo
# ShibInform
# andahazi
# StowawayArt
# LizClaman
# samcallah
# CarlosDada
# TheDustyBC
# SleepySharkBC
# JasonLes_
# DelCrxpto
# BrianRoemmele
# rockstar_stocks
# TrystineAnn
# JustinBennettFX
# ChristinaPushaw
# borsaressami
# ftchina
# Ugarles
# shibainuart
# galaxy_sidus
# RobMcNealy
# NUcontest888
# CGasparino
# AlexBemutated
# ShibainuCoin
# MesutOzil1088
# ShibaAustralia
# MajesticDrama
# SerkanArikan06
# traderjoe_xyz
# idealistkripto
# Jackmor98705125
# FEGtoken
# bcheungz
# marenaltman
# Kahinbey0
# barkleycapital
# Baris_Sma
# swapleonicorn
# TelcoinCom
# crypto_caesar1
# WatcherGuru
# Crypto_Wiza
# TomerStrolight
# Nordes__
# PorfirioChica
# BitcoinTina
# Ash00793
# 1bilginzvar
# shibainuevang
# NathanCRoth
# radioyskl
# VailshireCap
# NanoINDC
# kingppinn
# Benzinga
# ultimahsv
# ofnumbers
# yaaaaaaa0120
# projectquantum_
# bronzefozzz
# kevil_wu
# RealCoinGeek
# DamianCatanzaro
# dunyadanfinans
# wireframepit
# kandemirrmehmet
# GyroCommunity
# SenVarsannn
# katiewav
# 1_pageknowledge
# josenavarrosv
# Xposed
# deepfuckinghodl
# MineLikeAnApe
# entreprenoober
# silvioaquinog
# Noalospoliticos
# jonnylitecoin
# IncomeSharks
# raphschoen
# SunnyLeone
# Bleufiofficial
# NotABigJerk
# NYDIG_BTC
# Shibtrend
# NTmoney
# MartiWed
# BitplazaMobile
# davepell
# bendavenport
# BrittanyBitz
# _adembilican_
# believethehype
# ladycryptogem
# elsalvadorcom
# durowhale
# AltcoinSherpa
# CJ_Johnson17th
# Fatoshibsc
# TIME
# DaCryptoEye
# BullsForProfit
# purugyl
# punk6529
# LightRider5
# timevalueofbtc
# mghughism
# Crypto__emily
# stevedabitcoin
# relai_app
# Annabellatrade
# Ms_Logical
# AlexLary1
# hclav
# DWhitmanBTC
# CashBro_303
# BleepinComputer
# ultrasoundmoney
# Poisonbox91
# thelevelupexp
# Love_my_ripples
# tan_twtt
# kris
# shibainu_kanko_
# Shib_Guy
# TiarCrypto
# Elysianers
# CryptoPicsou
# ifyouneedmeida1
# dojotr00
# ElonMansur
# NfTsweetheart
# CryptoAnup
# hootan_saeidi
# Mand01Off
# MiningTk
# HannaButler_
# smashcashio
# CaCapital_
# enginyalcink
# shiepromotes
# NFTMasterclass
# Keremcrypto
# MarketRebels
# 9GAG
# ariffSomad
# NavalismHQ
# General_Oluchi
# NFAliens
# EricOfRivia
# BitcoinEkasi
# BusinessFamous
# SouthPark
# BabyGhosts_NFT
# Cryptoinvest__
# Strike
# Heatinblack
# vincent13031925
# OtunbaCoff
# TheBriDen
# SakshamSolank19
# Drwhales_
# KanutoTakumi
# RAMIROMARRA
# mercadosyaccion
# BscPitbull
# lemonapp_ar
# EhlenoCrypto
# CryptoBoostMe
# furrincrypto
# crypto2000news
# ApeKidsClub
# elsultanbitcoin
# pablowasserman
# bull_bnb
# UTXOmgmt
# TheBirbNest
# JesusCryptoHoDL
# GAContest_
# satstackerMY
# cryptoandee
# Ben_000777
# NastyShib
# Bitbro10
# givp
# BloombergLive
# izzyb0i
# NathanHeadPhoto
# peterhuntcrypto
# CarlBMenger
# MinersDefi
# Kr00ney
# blackbeardXBT
# grace_kalbo
# patriciomolina
# MrBeast
# Abyzeth
# sora_bkk
# chitaglorya__
# GT3_BTC
# shen_shiwei
# QuatreFinance
# LuckyCorgis
# eybonluis
# Craaazy_Unicorn
# aston_ed
# NatashaCryptoUS
# x7_rjx
# SHIBrumours
# Davidbanksz
# PresidenciaSV
# LiebermanAustin
# Suzuki_DX_
# lif_e_Tm
# silverguru22
# LevelUpCrypto_
# engadget
# AaronRodgers12
# JaxGallo
# sartoshi_nft
# MonicaLongSF
# federico_G_
# tommyk____
# cryptophile_btc
# DrJoeReed
# inmortalcrypto
# BusinessInsider
# HHorsley
# TheBitfi
# huibmodderkolk
# MMWYPcom
# VillaFernando_
# NumbersMuncher
# Convertbond
# Durad_A
# officialTifiola
# bponsot
# Trabzonspor
# DustinPlantholt
# runtheirstops
# timigod
# Al_ameen_Yabo
# SwiftOnSecurity
# Rohan_Naidu
# Bencjacobs
# SInvestments2
# MikeMcDonald89
# EdinamKlutse
# teopolitik
# Mision_Verdad
# RealSnowlove
# CryptoMagical
# nixcraft
# Fayokunmii
# davecoin_DDTG
# Crypto_Ed_NL
# Altcointraders_
# ayanda_yandiey_
# Radebe_merci
# kyosantou347
# thibm_
# DMTLAND_
# Prosonomasia
# carlosbremerg
# CNNBusiness
# Auta_Musa_
# ClichesDeJigme
# vicehii
# ComingSoon44
# ahkyee
# frankiemacd
# campuscodi
# potapac1
# CointiplyFaucet
# quintero_btc
# soyladeltango
# rogin03
# shad_plug
# GridGamingIO
# Oly245
# SafdarAlam
# lisaabramowicz1
# RuneExchange
# Slasher
# bitcoininfo
# EthPrime
# TheJonnyReid
# kasihodl
# BitcoinBankCash
# realSologenic
# TheHackersNews
# notcapnamerica
# ashley20196
# TheEricNorris
# cryptofhm
# Daniel_BATS99
# iPatricia_Btc
# shesek
# JoForLiberty
# Campaign_Otaku
# Cs_Ref
# Bakkt
# ineedmoneyxbt
# yanisvaroufakis
# Alexintosh
# bitpr0
# legolas282
# USAO_LosAngeles
# PatriciaSwitch
# Jkylebass
# secgron
# Promaz02
# DailyCaller
# HuffmanForNC
# vipgameio
# piersmorgan
# _oluwatobiiiii
# mikko
# theeHellGod
# willahmed
# MollyMcKew
# DearAuntCrabby
# nuafriksupport
# CoryBooker
# HackingDave
# neal_katyal
# SixArmedSweater
# dhershiser
# NotZkto
# abickford68
# CourthouseNews
# AnarchyRabbit13
# ramchrisali
# sophy_cherie
# Undoomed
# Postsubman
# PopCrave
# ashishjr07
# Mexiconomics1
# MilannYadav
# SkyNews
# davidhogg111
# LugnutX
# LordHookage
# AP
# Cernovich
# TechnicallyRon
# bagofnuts_
# selectedwisdom
# InfosFrancaises
# PeteButtigieg
# morphonios
# Kitboga
# AstroKatie
# tylercowen
# Avast
# 0x49fa98
# descifraguerra
# MariannaReports
# Finanzas_Times
# MattZeitlin
# SarahJamieLewis
# JProskowGlobal
# oneunderscore__
# PMBreakingNews
# nickstatt
# damntoledo
# lemos_ronaldo
# briankrebs
# SavinTheBees
# MacRumors
# hacks4pancakes
# GizmodoES
# Justin12393LEE
# disinformatico
# BrandonButch
# YemieFash
# VersaceAbi
# KickEcosystem
# n1ckchong
# FlamaToken
# TheCryptoFam
# MistaChips
# fimiletoks
# publordhodl
# BTCC
# paulofilippus
# nonfungible_eth
# GetCoinZoom
# AnnelovesSB19
# marcswane
# bullhiro_crypto
# AldoLebowski
# redphonecrypto
# BitSkinsCom
# ExcelTrading1
# C_Bendiksen
# RickiLake
# DNPthree
# Crypto4chun
# CarpeNoctom
# RayDalio
# 21MillionTV_
# freecashcom
# Pickle_Nickson
# AO1379
# myHoodies_onYou
# Obasisam_
# eoghan
# mattunchi
# DrOlufunmilayo
# cryptopilot16
# gokhshteinmedia
# BitcoinRothbard
# LilMoGh
# gbolahan_falana
# TheSeaVerse
# simonlutz21
# ICuRaRook
# syztmz
# Logic301
# BKGolf4
# HeimdallLand
# TheCryptoBubble
# Bad_J0ker
# VascodaGama
# girevik_
# beautyofhelin
# lorenzofb
# amberkanwar
# AshAgony
# starkness
# thatzenboi
# fernandoulrich
# EdgeWallet
# PhilCrypto77
# yungshapez
# George1Trader
# limitstream
# rapheal_olayode
# PLK5280
# Popehat
# melochcrypto
# davidmarcus
# gospel_harmony
# aquariusacquah
# vincentdesmond_
# zargoi
# PicartsoPotato
# Gift__Chill
# LanreF83
# seunnyc
# bitcoin_scripts
# PayPal
# ExTechOp
# tomgara
# AntoinetteIsama
# PoorRugOfficial
# alexrkonrad
# Mimalee_
# jonmatonis
# ireaderinokun
# Mathiasamodu
# Polkadot
# feminist_co
# Shawnifee
# Ajatz02
# DoubleEph
# nayaofficial01
# unicodeveloper
# Tspiceskitchen
# Bisola19
# firstladyship
# cerebralistic
# PaschalNwafor_
# llemurn
# TejuAdeyinka
# TheIgboWolf
# iamleoralph
# LXRE__
# nk4nuella
# jaido_p
# EmekaAmakeze
# OrientProject
# _bitcointoken
# TonyCai_
# wlrvs
# defidami
# Mr_LSD_Crypto
# Mine2Rr
# toluogunlesi
# DMM_Bitcoin
# rogueboykillua
# Dope_Tokens
# HikmetHajiyev
# ShStepanyan
# jimepstein
# CepnikMaciej
# decoin_io
# CryptoCollect19
# ari757
# MorphChat
# lubrio
# SunnyRayShow
# stedas
# goddersbloom
# TheJusticeDept
# Mippcivzla
# nikhilsaraf9
# WIRED
# VTVcanal8
# CynthiaDRitchie
# REIMAGINE_2021
# SovrynBTC
# gannycoz
# yffiifinance
# HuriShimaX
# Duelbits
# USA_Anne711
# stephendpalley
# ThinTallTosin
# abitcoinperson
# DamionOnNFTs
# NickGiambruno
# tumi_monakhisi
# JackPoolFinance
# cgimmer
# PaavoCoin
# PompPodcast
# aomra_00
# montymetzger
# tariqnasheed
# betrefscom
# Rydonofficial
# BenJessel
# StellarBattle
# adewalekemi65
# dlike_io
# drakefjustin
# nengiofficial
# joshtpm
# nikaBtc
# NGRSenate
# ikhide
# paraschopra
# TrezarCoin
# philiprosedale
# DominicFrisby
# Alpha_Reeyah
# CryptoBac
# k_rtp_
# EricMandela
# visbitcoin
# ugurses
# Intibonomo
# ruskin147
# RBReich
# Crypt0Ramb0666
# jasonzweigwsj
# JED_FUT
# danielmarven
# MrMessenger
# fahyadak
# mhartl
# BarbarianCap
# karirmuid
# bopinion
# KemiOlunloyo
# StockMKTNewz
# kreptplaydirty
# iamdihealer
# KEEMSTAR
# Sonnenshein
# BoogieCrypto
# mdbaccardax
# jillrgunter
# RepTomEmmer
# BitcoinKen
# tedaselectricas
# thalr_io
# BradMunchen
# lohstroh
# Bosslogic
# BBCBusiness
# FinancialTimes
# kanpo_blog
# FOS
# mashable
# benedictevans
# joshuaodeyemi
# EditiEffiong
# allanraicher
# Graceismyfaiths
# Shetudeary
# iyaboawokoya
# Matilda93908696
# IAtalkspace
# TachaSmile1
# SynfullyRite
# nftblockchain
# hfangca
# DavidBegnaud
# cryptofrank01
# the_davidatta
# SkillzbyTimi
# gmekhail
# hodlXhold
# Abdullahiabba_
# alexnurreo
# Mohnice_
# Iam_bodunde
# AishaYesufu
# mrmacaronii
# ayemojubar
# ThePaulOla
# SmartAtuadi
# debola_femi
# thetoluoflagos
# thecableindex
# akanziri
# TheHolyman_
# Omojuwa
# daddyoyoyoo
# chrisnuzi
# swagnito
# VictorIsrael_
# SaharaReporters
# FS_Yusuf_
# hackSultan
# adetolaov
# hardeckxpro_
# johnodonnell21
# JamesCageWhite
# RyanTheGentry
# hodlhodl
# _AsiwajuLerry
# JeffGrossPoker
# CointelegraphMT
# ubycohubng
# benaddi_hamza
# desmond_ibude
# sendai4roh
# 3ChicsPolitico
# CommunityFlare
# econoalchemist
# BankXRP
# MeekMill
# Lutufox
# viewsfrance
# alexisohanian
# xataka
# El_Citador
# Crypto_Ciara
# camanishnegi
# wallstbetsmafia
# AhmadDavisPR
# JustinAHorwitz
# CoinMetro
# Fritzanity
# seanonolennon
# Delikwu
# JeffAllen71
# Albastore001
# ArjunKharpal
# m_w_peters
# fchollet
# TommyThornton
# Sabi_boyz
# ElevationToday
# pitharoy
# KingtuttX0
# takumiasano_jp
# inthepixels
# MWietersheim
# abztrdr
# mikeinspace
# parman_the
# DVSblast
# cousincrypt0
# ConfirmTips
# heisizumichaels
# panekkkk
# Eaaaw
# izuchi_ejiogu
# KingSpencer100
# Robert_Klondike
# BrandyLJensen
# CryptoGroke
# MartinSLewis
# chosensomto
# thewilfem
# Hardforkers
# RAEinforma
# marttimalmi
# WillingAndreT
# MichaelRihani
# OvieNews
# shakathecreator
# cryptoquant_com
# ianbremmer
# renft_protocol
# nickcarter
# afrikantribe
# Dortmund4u
# jeffbarnes360
# germanee05
# driipdaklothier
# Letter_to_Jack
# erikblokland
# jmolinareyes
# roryhighside
# PeterMurrelI
# zenism_jp
# Anufadele
# DragonflyJonez
# 0x_Yuzu
# qbeeert
# KurtogluKagan
# GoatSwapfi
# Dymaxion
# ghpex_official
# Polylunar_
# TuncayULUDAG_
# Arthur_0x
# Siratthaya
# okx
# blackb7x
# TrackingEDDA
# ORHANOSMANOGLU
# asiahodl
# JacquelineSKTs1
# Increasity
# chainx_org
# bitfield
# ProtectionArmy
# caslernoel
# marcos_galperin
# BitcoinHorseman
# ithayla
# NLGNMANAV1
# DavidFantazzini
# itszhutwt
# oaktreefinances
# MyNeighborAlice
# UnderdogDefi
# RoKhanna
# Crypto_Penn
# CJMcCollum
# pcstandfor
# irmaga_umut_oll
# principe_viii
# cryptounfolded
# CerfiaFR
# Carasa_Gadsden
# WillyrexYT
# TheEpicDept
# 0xBitcoinBaddie
# nagomihana1
# TradutordoBR
# reptheset55
# Shine_McShine
# Bee_Kirby
# camaradamaciel
# _FloMilli
# investvoyager
# tferriss
# franamati
# Ekynos
# Ledger
# arvalis
# king_vidal96
# qrcapital
# PowerHasheur
# JMellerud
# sergiolugo
# madcapslaugh
# cnLedger
# frxresearch
# StreetBetsWall
# ViralErik
# elrama_
# stevewilldoit
# seinfelddahog
# JeffriesDavid23
# KevinSvenson_
# CedYoungelman
# ChrisKnight407
# robertjdenault
# N8twon
# mengxilu
# TruthGundlach
# RealVision
# FrankMcCourtoff
# martinlazarte17
# ilkerkarli
# CoinDeskjapan
# sandeepnailwal
# EnterNFT
# TheBabylonBee
# varcharian
# MaryfoxCrypto
# boltactionbeaut
# MehmetArdic_
# CryptoTony__
# bitcoin_paris_
# julianrademeyer
# bigmarh
# ikbldrs
# joabaldwin
# Web3Lewis
# freedums_dude
# aboladejohn_
# setremavi
# KophieMahn_
# BigSammy__
# btcDiamondHands
# TradesTrey
# adamscochran
# bit_gossip
# ChazSchmidt
# thebigfatj
# nukimaruda
# Victor_Fasina
# isaacstonefish
# CouRageJD
# JakeSucky
# weed_miner
# youngthug
# Omar_PrietoPSUV
# cryptoaddict86
# CrptoVIPsignal
# OfficialXRParmy
# DigiByteCoin
# guido_meijer
# tahsinhasoglu
# Negentropic_
# bsc_chase
# OracleHawk
# VeyselYurtsever
# _ErkanOz
# bilim_adami
# mrlethee
# Greekstein
# paubengero
# StonksReddit
# kriptofero
# JulianMaciasT
# ggreenwald
# ctoLarsson
# zndtoshi
# gossipboyz11
# JoshChambi_KE
# CountBitcoin
# JuanCafecito
# dhh
# DiligentDegen
# The_nExt_wRoNg_
# Frozentill
# realAlexBlank
# argonerd
# socialistdogmom
# maxberger
# Austen
# koush
# comma_ai
# WLFOFMYST
# KimZetter
# profgalloway
# brucefenton
# RationalEtienne
# glxyresearch
# cryptorecruitr
# forever_hodl
# HoldingTel
# TRF_Stories
# LucaLand97
# jaltucher
# tezos
# fakemommy
# LimitlessKrypto
# MoonliftCapital
# HenkelGarcia
# MarkJCarney
# lunaticoin
# thisisbullish
# Elisabeth_Steyn
# _whitneywebb
# RichardWellings
# Mz_kaba
# jakebrowatzke
# Elsa_Trujillo_
# MoneySaverSA1
# pinchycoke
# AlexEpstein
# atomicthumbs
# Lilmook4real
# XRP_Productions
# ndvoskin
# andrewschulz
# theserfstv
# KILLSHOTCRYPTO
# MikaelThalen
# CryptoBull2020
# MagnifiKent_
# porquetendencia
# ThaDogeQueen
# WhoIsClayJames
# LinksBTC
# EvansTed101
# only1doge
# CredibleCrypto
# rollbitcom
# CryptoVeneco
# Araimerahhh
# ricburton
# edwardmorra_btc
# CryptogramTR
# errcraft
# evdc_network
# bitcoin10095828
# NdrewsTjan
# ColinKeeley
# XolaneNdhlovu
# dogelettuce
# BinanceES
# SusanLiTV
# BESTokens
# plebsmemes
# HYPEBEAST
# Krypto_Nomad
# jennyyangtv
# haversfleeted
# johnauthers
# Thee_mavERIC
# ausch10s
# nosoyabriI
# Its_Davis11
# thxTopBoy
# unclebayotics
# JaynaijaBlog
# tiosimonbolivar
# AnoushkaReeves
# Alvis_KHamilton
# 8burgerz
# munna_30_
# Sakastweet
# norcoreano
# unhilo
# Moose18591680
# Sofidicecosas
# belafeid_
# _chiisom
# notEezzy
# bbbolsa
# khun101010
# freelanceburner
# HotepJesus
# crazeclown
# tculpan
# Colonel_edu
# fbgswiper
# AniceLajnef
# RoportajAdam
# incisozluk
# RileyWhittMusic
# deoors
# CptHodl
# 3Stocksaday
# YasirBoss99
# kholiatk
# an_shoo_
# DrOlusesan
# Okamo_career
# sushmita_sonii
# LuckyGoldx
# SMarie5907
# Udedibia
# JesseCohenInv
# davidturos
# ran_the_numbers
# navedelmisterio
# alexander23
# ClimateHuman
# VandelayBTC
# c0insbit
# MrsT106
# gregzaj1
# _JonnyLawrence
# wppenergycoin
# nietzbux
# MatthewLINY
# ProgrammableTx
# nylo44
# InuKishu
# princessofdoge
# Ebeeme13
# startupdareal
# ChloeWhiteAus
# hiltzikm
# satofishi
# dogecoin_empire
# AirShippedWorld
# Big_Vision_GR
# TESLAcharts
# WSBGiveaways
# RichRogers_
# EylemCulculoglu
# h_bitcoiner
# realDogecoinOG
# juicecrypt0
# jeetsidhu_
# JimmyWinSV
# neau_bsc
# OwenSparks_
# ivanngutierrez
# AntiDanilevski
# erikwill
# bit_maniak
# aiyshesu
# CryptoKingApe
# camilacampton
# christinebarnum
# ilhangunes58
# iamtheidentity
# ChartsBtc
# LunaOi_VN
# Wizardara
# monicataher
# basedkarbon
# cryptokudo
# TheAmateurInvs
# DarinFeinstein
# SteveUsingWords
# KP24
# Crypto_Dragon0
# esquivelgerardo
# BtcpayServer
# Relicaworld
# ZZulfikli
# BomsteinRick
# CryptoGodfatha
# LoveIsBitcoin21
# JBmastercrypto
# BeffernieBlack
# HederaCashgraph
# godeLives
# Sara_AyalaSv
# BitcoinKeith
# Isomibala
# DiarioCoLatino
# Avalorama
# venturefounder
# DavidZell_
# AfricaStoryLive
# Forza_Crypto
# GabrielCuellar
# Dooowta
# mybroadband
# Stalingrad_Poor
# SinoCrypto
# MoonBootsCap
# ObsoleteDogma
# MikeVechain
# BankOfIndra
# Wayne521G
# nahilshayk
# moonbtcb
# Shivansh_io
# AltcoinPsycho
# GabrielShipton
# d_adewumi
# EulerRodriguez7
# phuckcoin
# onlyyoontv
# billywhizz1970
# EAGPsting
# itskim_D
# koidoodles
# SuperDexFinance
# dwallacewells
# febridiansyah
# jimetsu_yaiba
# Leorzhang
# shakespeareprof
# CryptoNewton
# CNET
# ghcryptoguy
# ZaFaDo72
# You_Zan_
# Avik
# SafeDoge
# pitdesi
# darrenrovell
# chrambrosio
# DiarioBitcoin
# HerbertEsmahan
# MailOnline
# Newsweek
# Teaching_Crypto
# ChrisGuevaraG
# bbcmundo
# FranNicolas_G
# DogeAmillion
# carlhancock
# SimonLevyMx
# YuzoKano
# ReutersLatam
# Beautyon_
# TerukoNeriki
# castesalva
# edcarpenter20
# TeslaTruckClub
# Jason
# PabloSpyer
# francispouliot_
# santhoshmenam
# Stillm4n
# CryptoGucci
# Danology10
# MrJurose
# MasonRothschld
# BitDogetoken
# CryptoGraphBSC
# BollingerBeans
# ethereum_max
# KingDoggoXRP
# Ant52529536Jose
# JustinScerini
# stonecoldpat0
# CNBCi
# TYonClubhouse
# sircryptotips
# Zayfus
# Amir44328713
# thefatbitcoin2
# GLITCHYBSC
# Dogecoin_Aus
# MyCryptoAzure
# yourcompanionAI
# JamesClear
# _amymadison
# a115wanderlust
# btc_hagitori
# CryptoBethany
# iLiquidatebots
# fastbitcoins
# tokenterminal
# diamondhandzz
# BithumbOfficial
# MiAiimii
# CryptoElwis
# CutieBabeGem15
# Shibelon_MOON
# DaboubJorge
# HernandezJC_81
# _sanricardo
# YadavPramod171
# PlugAstro
# renepickhardt
# WiseAnalyze
# genXstacks
# RICHTVLIVE
# SpinelToken
# honey_xbt
# gokhanozbek
# kuapefinance
# andezpextor
# arquiguru
# ChaMali_Lychee
# CryptoBaxteer
# W_1_275
# GoodValueCrypto
# madorni
# BitcoinisUnity
# littlefreak0923
# AltruToken
# neoliberal_dad
# siasatpk
# MehmetHasanEken
# BrendonShanil
# Great_Tony1
# Marketsbylili
# YorubaRepublic
# Jnkfff
# textfiles
# BitcoinSampo
# Mattlucz
# adamconover
# passytee
# CryptoWillou
# crypto618
# coinwind_com
# kimchan_btc
# rettlerb
# NBCNews
# VextPro
# CBS_Herridge
# HaloCrypto
# Safemoon8701
# fmkhabib
# vxunderground
# Next100XGEMS
# TheBlockTake
# YPekcaliskan
# ColdBloodShill
# cryptoneo17
# jonchenot
# robustprotocol
# MirceaQuotes
# Phase1Token
# sportemongo
# dexkit
# TokenStudent
# coinpost_kagami
# Cryptojaguars
# Promodio_Token
# louishliu
# 1OF1Token
# glitchytoken
# flooz_inc
# HardDriveMag
# cryptoQUEEN_Q
# promotionfairy
# Saint_BTC
# CryptoLegacyEN
# btcbullanon
# hiiiiii3333
# ActuallyNPH
# ClimberBTC
# LiTOfficiall
# therealcsparrow
# ronaldnzimora
# JoeUnchained
# BitcoinUndisc
# SniperNextgem
# crypto_anan
# NicolasFlamelX
# mindfulbtcboss
# musikeys1
# WolvesFinance
# stizzynakamoto
# TheDeadNFT
# Saramonroesv
# st4rnold
# rrhdoteth
# CoinhuntCC
# SequentialTrade
# wongisrite
# IMFNews
# FCDenni
# OpenNode
# preston_hodl
# DizzleCrypto
# nelsonpaffi
# LucasOutumuro
# BigSky_HODL
# xcryptomaniacx
# Boniface1905
# CRAMSV
# TboneHODL
# Finsightnews
# alxberman
# SecPrensaSV
# Valebluem
# cponlife
# LonerTeejah
# BitcoinIsaiah
# RuleXRP
# TheStreet
# gersonmartinez
# _k3tan
# AmandaCerny
# FenixUlloaVP
# alexandre_lores
# Heng_Un8778
# Titans
# BenTodar
# CryptoJax69
# 2domeno_kami
# OfficialBTCE
# RiverPosner
# rosearmy1305
# seankelly25
# CryptoManiaks
# nywolforg
# JStein_WaPo
# oReXo3
# TrustWallet
# emilychangtv
# jessicasmw
# SuperPomer
# Wander_Token
# giovsr__
# MacroCRG
# BigM33sh
# crypto_pikachu1
# fiallaJD
# michitubbie
# CryptoBoomNews
# EssyBezzy
# momentsmarket
# AnnoraSteve
# ChristianDiffer
# GiveawaysCindy
# Mandrik
# tethermoon
# keplerswap
# CocoCryptoApe
# proyectopoder
# CAPTAINPLANETGH
# CarlRoegind
# teto_btc
# deathtospinach
# carlo_armilo
# fredericbeeg
# nqobile_mahungu
# BOOSIEOFFICIAL
# MiningProtocol
# realpartydoge
# kaekae_style
# DepartmentOfBTC
# thugbirdz
# sawa46493
# ibisofficial
# RTVCes
# ApesofSpace_nft
# BinanceUS
# devchart
# TheEconomist
# BorjasBojorquez
# NoCentralAuth
# j0hnnyw00
# Boris_Gauty
# QS_Holdings
# JC1oAxgs4D6D3kc
# MoonManT
# FranciscoPoleoR
# GreffMichael
# WKahneman
# Raul_Marin_
# azorcode
# AriZonanHODL
# geekboyireland
# SHodyEsq
# UberFacts
# UnityswapDEX
# PetizaGavarrete
# BonusCakeBSC
# alt_9774
# bixxxin
# DaikiPromotes
# ElenaCryptoBaby
# Ste_Cha_FEG
# thetrocro
# AxeCapYa
# eric_lombrozo
# ClementWardzala
# LuquitaRodrigue
# Necko_sv
# JohnNosta
# DSAccelMarket
# RonaCrypto
# compass_mining
# deezy_BTC
# ShiborgToken
# JGraphics9
# SafemoonSurgeon
# EleanorTerrett
# RealFlokiInu
# dallasmavs
# tailopez
# CryptoAtlasYT
# slpng_giants_pt
# CptHunchies
# 0xJim
# TuViejaTurner
# tommykripto
# Max_Nimiq
# JanWues
# mmmifla
# NFTBUZZNEWS
# ChadReddings
# 1rtuMu61pJwZPmF
# HEXkong
# ZinuToken
# thecryptoc0up1e
# Mason_Jappa
# dingertoken
# celestineia
# NFL
# divineanarchy
# Cafeine
# Crypto_Hawkk
# FireHost77
# all_things_btc
# JeremyCom
# NFL_Stats
# MySportsUpdate
# SportsCenter
# MikeGarafolo
# mercedeesse
# MichaelLevin
# max_gagliardi
# TomBrady
# Isekai_Verse
# InvestRuiz
# EarnYourLeisure
# treedefi
# ShibReports
# Dogecoinxx
# CNBCMiddleEast
# Fydcoin
# AydinCGur
# PopulismUpdates
# VittoStack
# jclcapital
# ACthecollector
# allinargy
# jratcliff
# gchampeau
# EcoAcad
# kale_abe
# Reventxz
# leadlagreport
# FaboisMe
# Estadao
# JimSwiftDC
# FinanceFr1
# Super_Okina
# yb_effect
# themonaleo
# Mombasa_Kot
# kuzisatoshinin
# definately_ape
# ValkyrieFunds
# eamplus
# invest_answers
# MiningHabit
# andr3w
# themviralgoats
# Felippe_Hermes
# sylvkartika
# crivizone
# A100888
# TN90803803
# FlokiPad
# lisafriedrich_
# grycrypto
# haseeb
# SantManukyan
# ks_ortega
# coinacademy_fr
# Cryptopathic
# CryptocapoOO
# suthichai
# Gadgets360
# gauchoeddy
# ShytoshiKusama
# btcgoatboss
# DigPerspectives
# MrVigilanteBTC
# seidon_mounten_
# dottorbarbieri
# PremiumCryptos
# altcoinchad
# GustavoBolsa
# dakyne
# BRSFreedom
# ChannelNewsAsia
# CryptoDefiGems
# bitcoinpods
# AntonioTheMexi
# martintetaz
# CryptoKemal
# NYSE
# Mark_Crypto_off
# b_timbs
# Gemzillacrypto
# ActualidadRT
# NevDivecha
# DmitriyMolla
# PowerPixelKK
# Brett_FTXUS
# lucasdcf
# BTC_for_Freedom
# ellle_em
# UnkleAyo
# CryptoMoments_
# DonHizuno
# gkhosts
# nopara73
# SeptaTron
# avogroovy
# MrAndyNgo
# eCoLoGy1990
# Missypromotes
# Laissonslespre1
# nikunjmodi89
# TaraConnelly8
# naima
# onemanatatime
# bobbyclee
# aunlock101
# CryptoBoss1984
# ShcoobyS
# sengokuea
# crainbf
# bMoneyBSC
# jffrson3000
# henrychavez133
# julianhosp
# maxi_malista
# NikoJilch
# Bitcoinbro10
# RSSorg
# Trust_Dice
# migangelgarzam
# rero_teamcrypto
# JaiHoCrypto
# KieranGibbs
# natonlinesafety
# vilsonvedana
# StateFall
# CNNEE
# mikegermano
# crypto_salary
# RoflGandhi_
# aklingus
# Block_Dojo
# AIBCsummit
# ChemaTojeira
# erkascinc
# chiitan7407
# Roosterpromos
# crypt_guko
# obj
# WesleyBKress
# TheGoldPrairie
# WillieDLIVE
# WilliamSorianoH
# bitcom_exchange
# francisco110585
# thekriskay
# aqoeth
# YoHViral
# WilliamAlfaroSV
# bitfinex
# themmagraham
# petermiyoung
# FastestPayout
# GemHSY
# edz_lozano
# CryptoVonDoom
# WavePunks_NFT
# BryceWeiner
# Jgilbelloso
# Sergiufomo
# BNocomment
# SusieBdds
# cvo_crypto
# johnkvallis
# RepTedBudd
# labitconf
# yournotbbh
# kevinsekniqi
# BitMartResearch
# fmlidermdq
# KriptoSahintas
# cory_eth
# Plan_A_NOT_B
# siddaramaiah
# Rothmus
# iamDCinvestor
# ComicDaveSmith
# JonathanCohn
# Ezekielnfts
# LadyofCrypto1
# TonHor
# ranvijaylive
# shobanes
# takigare3
# nickgillespie
# LaurentLamothe
# JohalMiles
# TexasCrypto1
# AnonimoSV503
# AllenAu11
# qbencis
# BullishRippers
# MattchengBtm
# MrCuchilla
# BinanceArg
# arcbtc
# ericonomic
# cardano_daily
# iotexPad
# rssurjewala
# josepimpo
# DanyAlos
# negrunch
# elianhuesca
# FabiusMercurius
# mark_cullen
# BTCprettycoin
# XShibanu
# betty_ekems
# Kwebbelkop
# Sassychickie
# GioGGeorgioNFTs
# TomGiuretis
# CoinPartner_
# Nishi8maru
# btcdragonlord
# athisha
# DanyReyesGt
# iapezteguia
# GlobalBTCFest
# xdc_news
# kilrau
# UniverseTwenty
# DoopieCash
# INCIndia
# srivatsayb
# beasties_online
# mranewliz
# Haraprasad_
# SpiritOfCongres
# soluparatodosok
# TheEliteCrypto
# TheRealGodWhale
# softsimon_
# JanvanEck3
# farhan_oa
# ShibaInuBill
# m_murfy
# slavi_io
# BybitFr
# alisonjkershaw
# kit_sats
# DailyRapFacts
# kunalkamra88
# MagicInternetM6
# rpatrickmurray
# ChaseTheTruth
# AlejandroZelay9
# TraderMercury
# ShannonBrayNC
# offrecoroom
# BITCOINALLCAPS
# DailyLoud
# MatthewHyland_
# CryptObjektiff
# _electronicCash
# CryptoIslandInc
# eevee
# crism9n
# cryptosNF
# KlausLovgreen
# kailybuemi
# panicfomo
# harmonyprotocol
# RyanDelongpre
# SolanaDot
# BabyDogeCoin
# ToastOfCT
# dio_ianakiara
# Quamf_y
# K9NFT
# SavvyRinu
# MrPlanN
# bitcoinmemelib
# Alyattes_ALYA
# dr_orlovsky
# Wealth_Theory

# %%
dados_ = []

# %%
len(dados_)
# Out:
# 122

# %%
usuarios_cadastrados = []

# %%
len(usuarios_cadastrados)
# Out:
# 946

# %%
contador = 0
import nltk
import re
from sklearn.feature_extraction.text import TfidfVectorizer

for i in Usuarios:
    contador += 1
    str_ = Usuarios[i]
    user = i
    print(user)
    if user not in list(usuarios_cadastrados):
        datasource = datasource1
        for j in range(0, len(datasource)):      
            documents = []      
            documents.append(str_)      
            try:
                documents.append(datasource.loc[j, 'posts'])
            except:
                a = 0
            else:
                
                tfidf = TfidfVectorizer(stop_words="english", ngram_range=(1, 4)).fit_transform(documents)
                    #Compute pairwise similarity by multiplying by transpose.
                pairwise_similarity = tfidf * tfidf.T
                    #Then, extract the score by selecting the first element in the   matrix.
                simiscore =   pairwise_similarity.A[0][1]
                    #Format the similarity score to select only 4 decimals
                simiscore = "{0:.4f}".format(simiscore)
                    
                    #Finally, add the similarity score to the dataframe
                datasource.loc[j, 'Simiscore'] = simiscore
            #Compute the rank and add it to the dataframe as its own column
        datasource['Rank'] = datasource['Simiscore'].rank(method='average', ascending=False) 
            #Sort by the rank
        datasource = datasource.sort_values('Rank', ascending=True)
            #Select top 5 entries
        datasource = datasource.head(10)
            #Select relevant columns and assign to a dataframe called docs
        docs = datasource[ ["type" ,"Rank", "Simiscore","Introversion/Extraversion","Intuitive/Observant","Thinking/Feeling","Judging/Perceiving"]]
                    
            #adicionamos no mongoDB
        docs.values.tolist()

        new_value = {'user':user,
        'text' : str_,
            'personality': docs.values.tolist()}
            #client = pymongo.MongoClient("mongodb+srv://trality:paulo123@cluster0.nbdde.mongodb.net/2020_Bitcoin_name?retryWrites=true&w=majority")
        dados_.append(new_value)
        print('new_value[personality]')
# Out:
# APompliano
# CoinCornerDanny
# AltcoinDailyio
# nanogamesio
# cz_binance
# faveladoinvest
# DexiveExchange
# river
# GoingParabolic
# CashApp
# Bitsahara
# 100trillionUSD
# InstaSwap_io
# rogerkver
# tyler
# jack
# milessuter
# alistairmilne
# CoinDesk
# Bitcoin
# jchatterleyCNN
# MsHodl
# EduardoGavotti
# naval
# cryptocom
# SatoshiLite
# DTAPCAP
# PetroDivisa
# realMatrixport
# EshaanMenon
# satomichan0626
# PixbyToken
# Suheb__
# Cryptoking
# Cointelegraph
# justinsuntron
# CaitlinLong_
# DoveyWan
# ErikVoorhees
# charliebilello
# CNBCFastMoney
# danheld
# BithumbGlobal
# marcopologlobal
# cobie
# CryptoBull
# hodlonaut
# levijawn
# NexusOfficial
# TuurDemeester
# metaeconomia1
# MaxieRyan
# nwankwoesq
# Crypto_emrgency
# lopp
# AtomicWallet
# CryptoAdventure
# aantonop
# jchervinsky
# rektcapital
# woonomic
# crypto_birb
# TheMoonCarl
# cryptoshion
# DraxFTW_
# CryptoHayes
# Excellion
# btc
# Rhythmtrader
# nvk
# scottmelker
# WhalePanda
# crypto
# bgarlinghouse
# lightning
# bensemchee
# ftx_app
# sosjorginho
# juanrallo
# crypt0snews
# skwp
# BitShills
# binance
# bradmillscan
# nlw
# AngeloBTC
# DigitalAssets
# ALISON_airlines
# JoshRoomsburg
# nandszffc
# NostalgiaFlu
# jefimzao
# realsurgesolar
# fundstrat
# officialmcafee
# ANI
# RaoulGMI
# bitcoin_clara
# LinkupFr
# Xentagz
# blingfiapp
# AlyseKilleen
# coinvasity
# HsakaTrades
# parkeralewis
# cryptunez
# PeterLBrandt
# Bitit_Gift
# Travis_Kling
# Eljaboom
# NickSzabo4
# Bloqport
# bitcoinist
# deyonte_btc
# Lera_Mashigo
# PeterSchiff
# brandonlharris
# Rager
# coinpaprika
# cripto_vzla
# gutjahr
# BVBTC
# shadders333
# Delta_Exchange
# NgamoolaTweets
# _unwriter
# connolly_dan
# Pixels4youcom
# OmoMamaCele
# spiralbtc
# MustacheTommy
# NorbertElekes
# coindealcom
# MessariCrypto
# TPSOperations
# Tradermayne
# nwoodfine
# justChinks
# bitpanda
# MichellePhan
# ColeGarnerXBT
# IPGaming_YT
# boaserichard
# zackvoell
# KennethBosak
# CryptoTimes_mag
# pembertonrob
# amtvmedia
# thesahilsays
# Bitribeofficial
# IndiaAboriginal
# IvanOnTech
# indepreserve
# kerooke
# BitcoinBF
# IOHK_Charles
# coryklippsten
# Melt_Dem
# cameron
# GeoffLewisOrg
# GiveAndStake
# HuobiGlobal
# MMCrypto
# Breedlove22
# erikfinman
# BlvckDotun
# clarkmoody
# ScottLEOWarrior
# TheCryptoLark
# qtkyoo
# jimmysong
# BitcoinIsSaving
# BTSEcom
# trylolli
# ademolaarr
# nejc_kodric
# Btc_grinder
# SmileyGnome
# TimDraper
# RelevantPeter
# ODELL
# btc_dakara
# BarrySilbert
# whale_alert
# glassnode
# theRealKiyosaki
# kucoincom
# KameronBennett
# 1CrypticPoet
# jk_rowling
# Kristian_Kho
# PrestonPysh
# MartyBent
# HODLBitty
# Schuldensuehner
# scottsantens
# Just2Bueno
# LilMoonLambo
# zelaapay
# CryptoR0ller
# BleacherReport
# ShamsCharania
# McClellanOsc
# SDinwiddie_25
# girlgone_crypto
# Dogetoshi
# LinaSeiche
# DavidNage
# mhluongo
# matthuang
# gladstein
# benmezrich
# darlingtonreal1
# AsktoMandrake
# LucasNuzzi
# sharkybit
# nanillionaire
# Ripple
# exodus_io
# novogratz
# SquawkCNBC
# paulvigna
# missteencrypto
# ChangeNOW_io
# ArcaChemist
# f2pool_official
# BitMEXResearch
# BitcoinMagazine
# DGBAT_Official
# TanukiBTC
# feathercoin2013
# CryptoCronkite
# real_vijay
# AcervoCharts
# CountDankulaTV
# hibeekay_lee
# Cryptanzee
# Nouriel
# fiatleak
# DigitalLawrence
# purchasable
# coinbase
# galaxyBTC
# MattSenter
# alexadelman
# RosaRyyti
# BitcoinStimulus
# Coinkolik
# MoneyMan
# Ealvarezfight
# AlokVasudev
# prestonjbyrne
# BitcoinBrains
# VisionCryptoApp
# sthenc
# TeufeurSoff
# dan_pantera
# eTalentMoney
# Cele__Audu
# ally_praiz
# JuanPdeMungia
# ericnode
# BitcoinMemeHub
# bitcoin_brown
# yassineARK
# EmperorBTC
# CPSeduction
# ihatecodee
# JamesGRickards
# callmethebear
# Jidetum
# TheProleStar
# blockchainchick
# adam3us
# ForbesCrypto
# ToneVays
# mdotbit
# krakenfx
# LocalCryptosES
# JosephTodaro_
# Benaskren
# 0xElle
# Dehkunle
# BobLoukas
# stakecube
# Your_Girl_Mo
# robustus
# GibsoonCorp
# fintechfrank
# chainlink
# SHNDcoin
# gaborgurbacs
# MikeEMars
# MatiGreenspan
# juthica
# PARABOLIT
# whalepool
# HuobiWallet
# BitcoinLixin
# BTCsessions
# SterlingWitzke
# buycoins
# SwanBitcoin
# ercwl
# MarkYusko
# RD_btc
# KRMA_0
# TokenPocket_TP
# ALymphsLife
# CryptoHitmann
# balajis
# solana
# MrSurfvivor
# Taour_
# jackmallers
# TeoGarciaEgea
# Nakamoto_BTC
# saifedean
# Lone_wanderer8
# Evit_cani
# TaviCosta
# IamBitmannn
# DHannum8
# Vis_in_numeris
# AmoreLoveAmor
# truechaingroup
# paxful_India
# koinprocom
# VitalikButerin
# AcalaNetwork
# FTREFORMED
# RussellOkung
# play2earncrypto
# MaziSamson
# SanojaReinaldo
# gator_bitcoin
# AdewaleOTunde
# ojeohis_
# Auntyadaa
# caprioleio
# nnaji_kate
# pascalboyart
# christhebigmac
# mountain_goats
# The_Oracal
# BTChap
# CircuitSociety
# Codiox
# CRYPTOFIED1
# abhizz16
# UniPowerGroup
# davidgokhshtein
# CryptoBullRon
# CryptoFortuneT2
# billburr
# erigganewmoney
# CoinCornerMatt
# kittyDCT19
# PundiXLabs
# psycoGAW
# BitrueOfficial
# FIatEarthMaps
# Vetologism
# blockandchain
# MalwareTechBlog
# btc_for_etc2021
# blKKstar
# UpholdInc
# CryptoChihiro
# ericgarland
# meupedebitcoin
# WazirXIndia
# Cryptogirlczai
# FUBTC
# ToXsiK
# thejohalfiles
# real_mercyeke
# maxkeiser
# CryptoStewiee
# notgrubles
# LindaKebbab
# bitcoinzay
# Bquittem
# CryptoZeinab
# nntaleb
# yotanlim
# CoryTV
# wazapepe
# Base58Check
# WhoKM
# koeda201515
# tatianakoffman
# coinpicksjapan
# mcnicollme
# satsdrop
# gavinandresen
# paypdmofficial
# TheDaoMaker
# katecrypto0
# TheWorldsAMine
# bitcoinographic
# HRF
# TheCelsian
# pushpendrakum
# nikzh
# realmaxkeiser
# CryptoCred
# SecretsOfCrypto
# callummarkie
# pwuille
# bitcoincoreorg
# ArgosCrypto
# FinPlanKaluAja1
# BW
# LynAldenContact
# volker_btc
# MaatlaKgasa
# friedberg
# GeorgeAnthonyO1
# SchenolS
# spectatorindex
# BuyingEveryDip
# DocumentingBTC
# _benkaufman
# saylor
# ayewaken
# WhaleChart
# MacguyverTech01
# socialbrice_
# zerohedge
# CryptoCapo_
# mistcop
# Maison1472
# realfrankwilder
# QNTMami
# BitfuryGeorge
# SInow
# Crypto_Potato
# BugrraOzturk
# bitstein
# nypost
# benthecarman
# Pelabur_Bijak
# macguyvermedia
# SwingbyProtocol
# TecraSpace
# Crypt0kyuubi
# GiveAwayHost
# QuintenFrancois
# rivatez
# BigCoinCrypto
# ippatel
# KSI
# wolfipali
# rezarazali
# PeterMcCormack
# TrVon
# masmasjawabgt
# scoinaldo
# CryptoSlimer
# arambarnett
# CarlosMaslaton
# CharlieShrem
# AmitShah
# pete_rizzo_
# SpencerKSchiff
# imBagsy
# bainesy4886
# mishalederman
# iamjosephyoung
# stoolpresidente
# VersusBtc
# FranceCryptos
# bigbunnycrypto
# EllieFrost
# PrimeXBT
# levie
# FrancisSuarez
# RookieXBT
# loopooYT
# EdVanDerWalt
# Verox_AICrypto
# eqonex
# BCBacker
# sof1azara03
# Timcast
# luiscarrillo66
# DrBitcoinMD
# satyakumar_y
# FEhrsam
# n3ocortex
# EconguyRosie
# XFII_Tech
# AWice
# DavidHundeyin
# HerroCrypto
# PJanuel
# fastswapdex
# PPathole
# elonmusk
# liadiVIII
# WolfBritton
# Crypto_Daily
# WendySiegelman
# WClementeIII
# billcashidy
# theestallion
# dypfinance
# outfitter_the
# mowaseife
# KingPandah
# Bluzezs
# JaValeMcGee
# JustMiningFr
# gate_io
# Jotteee
# DONJAZZY
# Stocktrader
# yurumazu
# 3LAU
# kashhill
# VzlaUfo
# foloflow_
# cex_io
# obyn_designs
# therealjuicyj
# twobitidiot
# Casey
# Snowden
# Dostlar_Hanesi
# le_gorafi
# eha_news
# business
# coinflip
# blockchain
# DegenDefiYT
# ZubyMusic
# Bitstamp
# WeBlockEnglish
# thedailybeast
# StoneAtwine
# ShaanVP
# OpIndia_in
# kurtwuckertjr
# itsprettyjamie
# c_aashish
# BJP4India
# cakedefi
# PettyWap0
# Eric_BIGfund
# smritiirani
# narendramodi
# PiyushGoyal
# JPNadda
# StealthPay
# dmlayt
# xD4rKs0u1x
# CalifaPoppy
# freddier
# viniciussexto
# dbsbank
# Bybit_Official
# Square
# cryptowarriorr
# BetllerOfficial
# coinbeastmedia
# Trezor
# KennethDredd
# KittyCoinGlobal
# nfergus
# stephanlivera
# NeerajKA
# cryptonary
# ReutersBiz
# JacobCanfield
# AynRandPaulRyan
# parabolictrav
# wealth
# BitCokedotcom
# BlockFi
# CoinbaseExch
# AnChainAI
# Tarmexio
# webounty_io
# Tegadeyforyou
# CryptoGodJohn
# ConflictsW
# GoGalaGames
# BlockRating
# 1MillionTokens
# lawmaster
# SamouraiWallet
# LooneyTunes
# longtunman
# LuchoPoletti
# CryptoTownEU
# kaparthi_j
# SimonDixonTwitt
# BohrBitcoin
# HukAleksandra
# theasiwaju247
# cryptopigmedia
# byeagle37
# BigMan_Xander
# black_bhoy_
# Ibrahim_Bello_
# sametoolz
# Sweepsgg
# jbarro
# axios
# BTC_Archive
# biancoresearch
# kacperski719
# gonnassau
# NextWaveEFT
# cissan_9984
# Life_After_18
# ki_young_ju
# Psolemn
# Leishman
# mainakTdas
# NischalShetty
# 0xglitch_
# ObongRoviel
# PratikDunya
# bascule
# JonErlichman
# TansuYegen
# ck_SNARKs
# MrktMeditations
# Davincij15
# iamZatoshi
# mskvsk
# patriottakes
# bsvscreen
# aubreystrobel
# J0hnnyXm4s
# CobraBitcoin
# patonet
# haskologlu
# Lukewearechange
# GRDecter
# Fxhedgers
# PFTCommenter
# davidgerard
# abdullahciftcib
# GameofCoins5
# SFHShoops
# Scaramucci
# vhic_tore
# DzambhalaHODL
# JamesTodaroMD
# Irunnia_
# taopiphop
# GemGamenft
# Miz__maheeda
# LibertyRPF
# lexfridman
# zhusu
# DCLBlogger
# MrOdanz
# tehMoonwalkeR
# PlateauGirll
# satoshibaggins
# BradMichelson
# DrTONYAGBATOR
# WSBChairman
# LibertyBlitz
# CryptoNewsYes
# AllisonReichel
# tesla_raj
# trending_medic
# AtifRMian
# khannib
# fluffypony
# ihsansenocak
# latokens
# MikeProposes
# mir_btc
# whitenigerian
# DeItaone
# TonySparkOG
# CNBC
# GregHathorn
# CryptoWhalebot
# fishxbt
# bud_crypto
# locodeschamps
# channelstv
# altugozturk
# realMeetKevin
# dougboneparth
# Jackvladamir
# CryptoHornHairs
# BloombergTV
# TheStalwart
# IStandWithPYO
# crypto_rand
# tonjukuk
# YieldApp
# saylordotorg
# CryptoWhale
# carlquintanilla
# azeaybalam
# fatmadiyin
# pookleblinky
# qikipedia
# itsALLrisky
# clairlemon
# TheBubbleBubble
# JeffBooth
# trevorjonesart
# souljaboy
# AriDavidPaul
# AnitaPosch
# yemencankan
# MarketWatch
# beatsgordy
# thepaulosophy
# hasufl
# ValaAfshar
# jackdanger
# TeminatorTrader
# skyler_fs
# bokujyuumai
# FinancialGory
# saskilla
# KoichiTsunoda
# peris_ja
# Mediavenir
# foosgonewild
# RyanRotolo
# jordanbpeterson
# DanielaCambone
# bitcoinclips
# MorningBrew
# WayneVaughan
# CryptoTrendsz
# KimDotcom
# genesimmons
# EricBalchunas
# TheIrishCrypto
# TurnerNovak
# MattWallace888
# goto_nikkei
# noshitcoins
# EricHolthaus
# lindsaylohan
# renoomokri
# renprotocol
# marcvanderchijs
# BadgerDAO
# omg_keynes
# machineiv
# DreadBong0
# BrainHarrington
# moderate_ustaz
# 997_Carrera
# BrightJaye
# AfricaFactsZone
# Enitan_sam
# dergigi
# tradingview
# DogecoinRise
# shanstory
# RafaelH117
# dilutionproof
# Joeingram1
# krugermacro
# themotleyfool
# Izzy_Lu2xx
# ZevMintz
# HappyShillmore
# nic__carter
# LayahHeilpern
# Timccopeland
# shoegalnyc
# yocchan60
# KatieTheRussian
# dannydiekroeger
# abdulalimuk
# RobinhoodApp
# deech
# JoannaBlackhart
# C_Angermayer
# muneeb
# anilsaidso
# KinseyGrant
# metroadelantado
# Andrew_J_Howard
# iamkoshiek
# CryptKeeperBTC
# markets
# riki_sakamoto
# LEON9750
# CathieDWood
# news_of_bsc
# MadamClinton
# CryptoMichNL
# llamasoft_ox
# StarkWareLtd
# umbrel
# digitalassetbuy
# MartiniGuyYT
# Nicholas_Merten
# cryptowat_ch
# plan_marcus
# LukeGromen
# vogon
# satsie
# QueTesoro
# CoinCornerMolly
# elliotrades
# Cryptobabushka
# AsennaWealth
# jamesviggy
# DeFiHulk
# KetanJ0
# BitcoinCameron
# FirstSquawk
# Dogecoinrich
# TCR_news_
# CNN
# JohnOdetteMD
# philthatremains
# ohlalamilala
# SantiDiPaolo
# ivancarrino
# dimacgarcia
# ComplexMusic
# Complex
# trader_ferg
# DefiantNews
# YellowBlock_io
# jakepaul
# RARohde
# BitPay
# DiepSanh
# LatveriasDoom
# TechCrunch
# DeepFuckingDefi
# GrantCardone
# javiernavia
# YoungCryptoPM
# Sonjoe_Kutuh
# EmmaRincon
# knutsvanholm
# BitcoinSapiens
# MariaPesce_
# BITVOLT7
# Techconcatalina
# seyitaylor
# TosinOlugbenga
# Cokedupoptions
# bigd3bs
# RampCapitalLLC
# Reuters
# EricRWeinstein
# _bitcoiner
# hiropi_fx
# VentureCoinist
# thecryptomonk
# decryptmedia
# MacroScope17
# sk_cadi
# HaileyLennonBTC
# DeadlineDayLive
# EmekaNwaGuy
# JamesFourM
# RyanWatkins_
# RealRBHJr
# CoinPaymentsNET
# NobotoGen
# chrismelberger
# onybose
# BitsonicGlobal
# Earth_Jennie
# OlamideQuadri4
# Andrewstotle
# willcole
# ipvkyte
# smdiehl
# SalesNotepad
# JacobOracle
# surayaror
# dril
# lisekimhorton
# robertcaruso
# JuliaDavisNews
# RedTRaccoon
# MingGao26
# Crypto_Fridays
# denverbitcoin
# NickKristof
# Mpolymer
# dobuybitcoin
# WSJ
# klever_io
# RealSpikeCohen
# DrDenaGrayson
# splendidland
# YourAnonCentral
# SethAbramson
# brianschatz
# FrankFigliuzzi1
# MrShawnRogers
# hodloncomrades
# sparrowmedia
# donwinslow
# jjmacnab
# Y2K_mindset
# Quicktake
# ABC7
# AKiyoshi0605
# LizBitcoin
# camilladelucas
# tim_bitcoin
# Ujbaby12
# IGN
# DeribitExchange
# dealsandcoins
# new_value[personality]
# Rothbard1776
# new_value[personality]
# btcdarwinist
# new_value[personality]
# PrisonPlanet
# new_value[personality]
# alispagnola
# new_value[personality]
# ClayTravis
# new_value[personality]
# ParikPatelCFA
# new_value[personality]
# MRKR
# new_value[personality]
# PatrickAdemo
# new_value[personality]
# najihahshahrel
# new_value[personality]
# Erikcason
# new_value[personality]
# ashgoblue
# new_value[personality]
# nytimes
# new_value[personality]
# LisaKramer
# new_value[personality]
# ameero1
# new_value[personality]
# laevitas1
# new_value[personality]
# gustavo_srcc
# new_value[personality]
# gyaigyimii
# new_value[personality]
# alamin_ghost
# new_value[personality]
# Buffettsbroker
# new_value[personality]
# DaveInTheCut_
# new_value[personality]
# btc_quotes
# new_value[personality]
# litcapital
# new_value[personality]
# izzy9821
# new_value[personality]
# canalCCore2
# new_value[personality]
# HTDcris
# new_value[personality]
# Mochievous
# new_value[personality]
# Kingston_eze
# new_value[personality]
# kusssman
# new_value[personality]
# logos_id
# new_value[personality]
# eliasimos
# new_value[personality]
# MaximilianXCIX
# new_value[personality]
# ShutupRuss
# new_value[personality]
# lemasabachthani
# new_value[personality]
# billbarhydt
# new_value[personality]
# murdabeatz
# new_value[personality]
# didikins4life
# new_value[personality]
# JoelKatz
# new_value[personality]
# primalpoly
# new_value[personality]
# KotaTheFriend
# new_value[personality]
# PrasagaOfficial
# new_value[personality]
# michaelbatnick
# new_value[personality]
# IIICapital
# new_value[personality]
# asemota
# new_value[personality]
# luis_villegasr
# new_value[personality]
# stacyherbert
# new_value[personality]
# ICOffender
# new_value[personality]
# btc_racing
# new_value[personality]
# CryptSpecialist
# new_value[personality]
# ThaGuru_
# new_value[personality]
# aiautosng
# new_value[personality]
# GbengaGOLD
# new_value[personality]
# kigyo_seiko
# new_value[personality]
# twetchapp
# new_value[personality]
# saxena_puru
# new_value[personality]
# Jestopher_BTC
# new_value[personality]
# KelvinOssai
# new_value[personality]
# ChainlenkMyses
# new_value[personality]
# bfmbusiness
# new_value[personality]
# JasonYanowitz
# new_value[personality]
# BTC_JackSparrow
# new_value[personality]
# techwithcatalin
# new_value[personality]
# GaryLeland
# new_value[personality]
# WavesMediaNG
# new_value[personality]
# Zlatan_Ibile
# new_value[personality]
# Nerd_Stack
# new_value[personality]
# paoloardoino
# new_value[personality]
# VictoryAlex4
# new_value[personality]
# Uncle_sarm
# new_value[personality]
# FIREBTC1
# new_value[personality]
# Xenos_Giveaway
# new_value[personality]
# KatusaResearch
# new_value[personality]
# Naija_PR
# new_value[personality]
# russdiemon
# new_value[personality]
# greentoepalacio
# new_value[personality]
# iaboyeji
# new_value[personality]
# JE_dna
# new_value[personality]
# _EmpressSara
# new_value[personality]
# tobias31
# new_value[personality]
# XaviercMiller
# new_value[personality]
# zzabbits
# new_value[personality]
# swoph
# new_value[personality]
# KoroushAK
# new_value[personality]
# AmgMedikal
# new_value[personality]
# breakchainsmag
# new_value[personality]
# ecoinometrics
# new_value[personality]
# TheGod0fThunder
# new_value[personality]
# CoinMarketCap
# new_value[personality]
# IwanRabbinstein
# new_value[personality]
# No_Limits060
# new_value[personality]
# obi
# new_value[personality]
# ReutersTech
# new_value[personality]
# Grayscale
# new_value[personality]
# 0liminati
# new_value[personality]
# tracyalloway
# new_value[personality]
# AlexSaundersAU
# new_value[personality]
# gregory_raymond
# new_value[personality]
# garciabanchs
# new_value[personality]
# RCachanosky
# new_value[personality]
# savannahbrown
# new_value[personality]
# ajv
# new_value[personality]
# Diditaihuttu
# new_value[personality]
# cakman4
# new_value[personality]
# Blockstream
# new_value[personality]
# Froste
# new_value[personality]
# danorlovsky7
# new_value[personality]
# MKBHD
# new_value[personality]
# Bitvarna
# new_value[personality]
# Valeezy
# new_value[personality]
# iamchrisani
# new_value[personality]
# dmuthuk
# new_value[personality]
# dlacalle_IA
# new_value[personality]
# Morris_Monye
# new_value[personality]
# HSouthwellFE
# new_value[personality]
# ThomasEWoods
# new_value[personality]
# thenoelmiller
# new_value[personality]
# typerbole
# new_value[personality]
# chamath
# new_value[personality]
# the_ironsheik
# new_value[personality]
# austin_rief
# new_value[personality]
# dammie_remix
# new_value[personality]
# noahkaufmanmd
# new_value[personality]
# oloye__
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/paulo/Desktop/Faculdade/Faculdade/LCDIA/Tabela_Usuarios.ipynb Cell 18' in <cell line: 6>()
#      <a href='vscode-notebook-cell:/home/paulo/Desktop/Faculdade/Faculdade/LCDIA/Tabela_Usuarios.ipynb#ch0000019?line=18'>19</a>     a = 0
#      <a href='vscode-notebook-cell:/home/paulo/Desktop/Faculdade/Faculdade/LCDIA/Tabela_Usuarios.ipynb#ch0000019?line=19'>20</a> else:
# ---> <a href='vscode-notebook-cell:/home/paulo/Desktop/Faculdade/Faculdade/LCDIA/Tabela_Usuarios.ipynb#ch0000019?line=21'>22</a>     tfidf = TfidfVectorizer(stop_words="english", ngram_range=(1, 4)).fit_transform(documents)
#      <a href='vscode-notebook-cell:/home/paulo/Desktop/Faculdade/Faculdade/LCDIA/Tabela_Usuarios.ipynb#ch0000019?line=22'>23</a>         #Compute pairwise similarity by multiplying by transpose.
#      <a href='vscode-notebook-cell:/home/paulo/Desktop/Faculdade/Faculdade/LCDIA/Tabela_Usuarios.ipynb#ch0000019?line=23'>24</a>     pairwise_similarity = tfidf * tfidf.T
#
# File ~/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:2072, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=2068'>2069</a> self._tfidf.fit(X)
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=2069'>2070</a> # X is already a transformed view of raw_documents so
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=2070'>2071</a> # we set copy to False
# -> <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=2071'>2072</a> return self._tfidf.transform(X, copy=False)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:1672, in TfidfTransformer.transform(self, X, copy)
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1665'>1666</a>     X.data += 1
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1667'>1668</a> if self.use_idf:
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1668'>1669</a>     # idf_ being a property, the automatic attributes detection
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1669'>1670</a>     # does not work as usual and we need to specify the attribute
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1670'>1671</a>     # name:
# -> <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1671'>1672</a>     check_is_fitted(self, attributes=["idf_"], msg="idf vector is not fitted")
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1673'>1674</a>     # *= doesn't work
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1674'>1675</a>     X = X * self._idf_diag
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1332, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/utils/validation.py?line=1329'>1330</a>     if not isinstance(attributes, (list, tuple)):
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/utils/validation.py?line=1330'>1331</a>         attributes = [attributes]
# -> <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/utils/validation.py?line=1331'>1332</a>     fitted = all_or_any([hasattr(estimator, attr) for attr in attributes])
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/utils/validation.py?line=1332'>1333</a> elif hasattr(estimator, "__sklearn_is_fitted__"):
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/utils/validation.py?line=1333'>1334</a>     fitted = estimator.__sklearn_is_fitted__()
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1332, in <listcomp>(.0)
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/utils/validation.py?line=1329'>1330</a>     if not isinstance(attributes, (list, tuple)):
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/utils/validation.py?line=1330'>1331</a>         attributes = [attributes]
# -> <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/utils/validation.py?line=1331'>1332</a>     fitted = all_or_any([hasattr(estimator, attr) for attr in attributes])
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/utils/validation.py?line=1332'>1333</a> elif hasattr(estimator, "__sklearn_is_fitted__"):
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/utils/validation.py?line=1333'>1334</a>     fitted = estimator.__sklearn_is_fitted__()
#
# File ~/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:1692, in TfidfTransformer.idf_(self)
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1683'>1684</a> """Inverse document frequency vector, only defined if `use_idf=True`.
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1684'>1685</a>
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1685'>1686</a> Returns
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1686'>1687</a> -------
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1687'>1688</a> ndarray of shape (n_features,)
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1688'>1689</a> """
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1689'>1690</a> # if _idf_diag is not set, this will raise an attribute error,
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1690'>1691</a> # which means hasattr(self, "idf_") is False
# -> <a href='file:///home/paulo/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py?line=1691'>1692</a> return np.ravel(self._idf_diag.sum(axis=0))
#
# File ~/.local/lib/python3.8/site-packages/scipy/sparse/_compressed.py:624, in _cs_matrix.sum(self, axis, dtype, out)
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_compressed.py?line=619'>620</a>     return ret.sum(axis=(), dtype=dtype, out=out)
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_compressed.py?line=620'>621</a> # spmatrix will handle the remaining situations when axis
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_compressed.py?line=621'>622</a> # is in {None, -1, 0, 1}
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_compressed.py?line=622'>623</a> else:
# --> <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_compressed.py?line=623'>624</a>     return spmatrix.sum(self, axis=axis, dtype=dtype, out=out)
#
# File ~/.local/lib/python3.8/site-packages/scipy/sparse/_base.py:1100, in spmatrix.sum(self, axis, dtype, out)
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=1096'>1097</a> # axis = 0 or 1 now
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=1097'>1098</a> if axis == 0:
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=1098'>1099</a>     # sum over columns
# -> <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=1099'>1100</a>     ret = self._ascontainer(
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=1100'>1101</a>         np.ones((1, m), dtype=res_dtype)
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=1101'>1102</a>     ) @ self
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=1102'>1103</a> else:
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=1103'>1104</a>     # sum over rows
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=1104'>1105</a>     ret = self @ self._ascontainer(
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=1105'>1106</a>         np.ones((n, 1), dtype=res_dtype)
#    <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=1106'>1107</a>     )
#
# File ~/.local/lib/python3.8/site-packages/scipy/sparse/_base.py:626, in spmatrix.__rmatmul__(self, other)
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=622'>623</a> if isscalarlike(other):
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=623'>624</a>     raise ValueError("Scalar operands are not allowed, "
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=624'>625</a>                      "use '*' instead")
# --> <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=625'>626</a> return self._rmul_dispatch(other)
#
# File ~/.local/lib/python3.8/site-packages/scipy/sparse/_base.py:607, in spmatrix._rmul_dispatch(self, other)
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=604'>605</a> except AttributeError:
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=605'>606</a>     tr = np.asarray(other).transpose()
# --> <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=606'>607</a> return (self.transpose() @ tr).transpose()
#
# File ~/.local/lib/python3.8/site-packages/scipy/sparse/_base.py:620, in spmatrix.__matmul__(self, other)
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=616'>617</a> if isscalarlike(other):
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=617'>618</a>     raise ValueError("Scalar operands are not allowed, "
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=618'>619</a>                      "use '*' instead")
# --> <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=619'>620</a> return self._mul_dispatch(other)
#
# File ~/.local/lib/python3.8/site-packages/scipy/sparse/_base.py:554, in spmatrix._mul_dispatch(self, other)
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=550'>551</a> if other.shape != (N,) and other.shape != (N, 1):
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=551'>552</a>     raise ValueError('dimension mismatch')
# --> <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=553'>554</a> result = self._mul_vector(np.ravel(other))
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=555'>556</a> if isinstance(other, np.matrix):
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_base.py?line=556'>557</a>     result = self._ascontainer(result)
#
# File ~/.local/lib/python3.8/site-packages/scipy/sparse/_compressed.py:489, in _cs_matrix._mul_vector(self, other)
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_compressed.py?line=486'>487</a> # csr_matvec or csc_matvec
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_compressed.py?line=487'>488</a> fn = getattr(_sparsetools, self.format + '_matvec')
# --> <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_compressed.py?line=488'>489</a> fn(M, N, self.indptr, self.indices, self.data, other, result)
#     <a href='file:///home/paulo/.local/lib/python3.8/site-packages/scipy/sparse/_compressed.py?line=490'>491</a> return result
#
# KeyboardInterrupt:

# %%
aux = []
for i in usuarios_personalidades:
    i["user"] = i['user'].replace("@","")
    aux.append(i["user"])

# %%
usuarios_personalidades[0]["user"]
usuarios_personalidades[0]["text"]
usuarios_personalidades[0]["personality"][0]
# Out:
# ['INTJ', 1.0, '0.0529', 'Introverted', 'Intuitive', 'Thinking', 'Judging']

# %%
for i in dados_:
    usuarios_cadastrados.append(i['user'])

# %%
import csv

# open the file in the write mode
f = open('Dados_att1_.csv', 'w', newline='',encoding='UTF-8')

# create the csv writer
writer = csv.writer(f)
writer.writerow(['Usuario',
'Texto','Personalidade'
,'Valor_TfidfVectorizer',])
# write a row to the csv file
for i in dados_:
    writer.writerow([i["user"],
        i["text"],
        i["personality"][0][0],
        i["personality"][0][2]])

# close the file
f.close()
