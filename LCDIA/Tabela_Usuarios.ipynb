# %%
import pandas as pd
import pymongo
from bson.objectid import ObjectId
import csv

client = pymongo.MongoClient("mongodb+srv://trality:paulo123@cluster0.nbdde.mongodb.net/2020_Bitcoin_name?retryWrites=true&w=majority")
db = client.Bitcoin_

# %%
import pandas as pd
import pymongo
from bson.objectid import ObjectId
import csv


client = pymongo.MongoClient("mongodb+srv://paulo7676:boliboli09@cluster0.vdntu.mongodb.net/?retryWrites=true&w=majority")

# %%
usuarios_personalidades = []
for i in db.Col.find():
    usuarios_personalidades.append(i)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# c:\Users\paulo\OneDrive\Área de Trabalho\Programas\Faculdade\Faculdade\LCDIA\Tabela_Usuarios.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/paulo/OneDrive/%C3%81rea%20de%20Trabalho/Programas/Faculdade/Faculdade/LCDIA/Tabela_Usuarios.ipynb#ch0000002?line=0'>1</a> usuarios_personalidades = []
# ----> <a href='vscode-notebook-cell:/c%3A/Users/paulo/OneDrive/%C3%81rea%20de%20Trabalho/Programas/Faculdade/Faculdade/LCDIA/Tabela_Usuarios.ipynb#ch0000002?line=1'>2</a> for i in db.Col.find():
#       <a href='vscode-notebook-cell:/c%3A/Users/paulo/OneDrive/%C3%81rea%20de%20Trabalho/Programas/Faculdade/Faculdade/LCDIA/Tabela_Usuarios.ipynb#ch0000002?line=2'>3</a>     usuarios_personalidades.append(i)
#
# ...

# %%
client = pymongo.MongoClient("mongodb+srv://paulo7676:boliboli09@cluster0.vdntu.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
data1 = pd.read_csv("Data_2020_Final.csv", encoding = "ISO-8859-1")
data2 = pd.read_csv("Data_2021_Final.csv", encoding = "ISO-8859-1")
usuarios = pd.read_csv("Dados_Usuarios(Certo).csv", encoding = "ISO-8859-1")

usuarios_novos = pd.read_csv("dados_att2.csv", encoding = "ISO-8859-1")

# %%
usuarios_cadastrados = []
for i in usuarios_novos["Usuario"]:
    usuarios_cadastrados.append(i)

# %%
Usuarios = {}
for i in usuarios["Usuario"]:
    Usuarios[i] = ""

# %%
for i in range(len(data1)):
    try:
        Usuarios[data1["user"][i].replace("@","")] += (data1["texto"][i].replace("\n", " ") + " ")
    except:
        a = 0
for i in range(len(data2)):
    try:
        Usuarios[data1["user"][i].replace("@","")] += (data1["texto"][i].replace("\n", " ") + " ")
    except:
        a = 0

# %%
len(Usuarios)
# Out:
# 3783

# %%
personas = pd.read_csv("Personalidades_Usuarios.csv", encoding = "ISO-8859-1")

# %%
len(personas)
# Out:
# 500

# %%
usuarios_cadastrados = []
for i in personas["Usuario"]:
    try:
        user__ = i.replace(" ","")
        usuarios_cadastrados.append(user__)
    except:
        a = 0

# %%
len(usuarios_cadastrados)
# Out:
# 146

# %%
#Data_Frame_Personality
datasource1 = pd.read_csv("DataFrame_Personalidades_kaggle.csv")

# %%
contador = 0
import nltk
import re
from sklearn.feature_extraction.text import TfidfVectorizer

for i in Usuarios:
    contador += 1
    str_ = Usuarios[i]
    user = i
    print(user)
# Out:
# APompliano
# CoinCornerDanny
# AltcoinDailyio
# nanogamesio
# cz_binance
# faveladoinvest
# DexiveExchange
# river
# GoingParabolic
# CashApp
# Bitsahara
# 100trillionUSD
# InstaSwap_io
# rogerkver
# tyler
# jack
# milessuter
# alistairmilne
# CoinDesk
# Bitcoin
# jchatterleyCNN
# MsHodl
# EduardoGavotti
# naval
# cryptocom
# SatoshiLite
# DTAPCAP
# PetroDivisa
# realMatrixport
# EshaanMenon
# satomichan0626
# PixbyToken
# Suheb__
# Cryptoking
# Cointelegraph
# justinsuntron
# CaitlinLong_
# DoveyWan
# ErikVoorhees
# charliebilello
# CNBCFastMoney
# danheld
# BithumbGlobal
# marcopologlobal
# cobie
# CryptoBull
# hodlonaut
# levijawn
# NexusOfficial
# TuurDemeester
# metaeconomia1
# MaxieRyan
# nwankwoesq
# Crypto_emrgency
# lopp
# AtomicWallet
# CryptoAdventure
# aantonop
# jchervinsky
# rektcapital
# woonomic
# crypto_birb
# TheMoonCarl
# cryptoshion
# DraxFTW_
# CryptoHayes
# Excellion
# btc
# Rhythmtrader
# nvk
# scottmelker
# WhalePanda
# crypto
# bgarlinghouse
# lightning
# ...

# %%
dados_ = []

# %%
len(dados_)
# Out:
# 622

# %%
usuarios_cadastrados = []

# %%
usuarios_cadastrados
# Out:
# ['APompliano',
#  'CoinCornerDanny',
#  'AltcoinDailyio',
#  'nanogamesio',
#  'cz_binance',
#  'faveladoinvest',
#  'DexiveExchange',
#  'river',
#  'GoingParabolic',
#  'CashApp',
#  'Bitsahara',
#  '100trillionUSD',
#  'InstaSwap_io',
#  'rogerkver',
#  'tyler',
#  'jack',
#  'milessuter',
#  'alistairmilne',
#  'CoinDesk',
#  'Bitcoin',
#  'jchatterleyCNN',
#  'MsHodl',
#  'EduardoGavotti',
#  'naval',
#  'cryptocom',
#  'SatoshiLite',
#  'DTAPCAP',
#  'PetroDivisa',
#  'realMatrixport',
#  'EshaanMenon',
#  'satomichan0626',
#  'PixbyToken',
#  'Suheb__',
#  'Cryptoking',
#  'Cointelegraph',
#  'justinsuntron',
#  'CaitlinLong_',
#  'DoveyWan',
#  'ErikVoorhees',
#  'charliebilello',
#  'CNBCFastMoney',
#  'danheld',
#  'BithumbGlobal',
#  'marcopologlobal',
#  'cobie',
#  'CryptoBull',
#  'hodlonaut',
#  'levijawn',
#  'NexusOfficial',
#  'TuurDemeester',
#  'metaeconomia1',
#  'MaxieRyan',
#  'nwankwoesq',
#  'Crypto_emrgency',
#  'lopp',
#  'AtomicWallet',
# ...

# %%
contador = 0
import nltk
import re
from sklearn.feature_extraction.text import TfidfVectorizer

for i in Usuarios:
    contador += 1
    str_ = Usuarios[i]
    user = i
    print(user)
    if user not in list(usuarios_cadastrados):
        datasource = datasource1
        for j in range(0, len(datasource)):      
            documents = []      
            documents.append(str_)      
            try:
                documents.append(datasource.loc[j, 'posts'])
            except:
                a = 0
            else:
                
                tfidf = TfidfVectorizer(stop_words="english", ngram_range=(1, 4)).fit_transform(documents)
                    #Compute pairwise similarity by multiplying by transpose.
                pairwise_similarity = tfidf * tfidf.T
                    #Then, extract the score by selecting the first element in the   matrix.
                simiscore =   pairwise_similarity.A[0][1]
                    #Format the similarity score to select only 4 decimals
                simiscore = "{0:.4f}".format(simiscore)
                    
                    #Finally, add the similarity score to the dataframe
                datasource.loc[j, 'Simiscore'] = simiscore
            #Compute the rank and add it to the dataframe as its own column
        datasource['Rank'] = datasource['Simiscore'].rank(method='average', ascending=False) 
            #Sort by the rank
        datasource = datasource.sort_values('Rank', ascending=True)
            #Select top 5 entries
        datasource = datasource.head(10)
            #Select relevant columns and assign to a dataframe called docs
        docs = datasource[ ["type" ,"Rank", "Simiscore","Introversion/Extraversion","Intuitive/Observant","Thinking/Feeling","Judging/Perceiving"]]
                    
            #adicionamos no mongoDB
        docs.values.tolist()

        new_value = {'user':user,
        'text' : str_,
            'personality': docs.values.tolist()}
            #client = pymongo.MongoClient("mongodb+srv://trality:paulo123@cluster0.nbdde.mongodb.net/2020_Bitcoin_name?retryWrites=true&w=majority")
        dados_.append(new_value)
        print(new_value['personality'])
# Out:
# APompliano
# CoinCornerDanny
# AltcoinDailyio
# nanogamesio
# cz_binance
# faveladoinvest
# DexiveExchange
# river
# GoingParabolic
# CashApp
# Bitsahara
# 100trillionUSD
# InstaSwap_io
# rogerkver
# tyler
# jack
# milessuter
# alistairmilne
# CoinDesk
# Bitcoin
# jchatterleyCNN
# MsHodl
# EduardoGavotti
# naval
# cryptocom
# SatoshiLite
# DTAPCAP
# PetroDivisa
# realMatrixport
# EshaanMenon
# satomichan0626
# PixbyToken
# Suheb__
# Cryptoking
# Cointelegraph
# justinsuntron
# CaitlinLong_
# DoveyWan
# ErikVoorhees
# charliebilello
# CNBCFastMoney
# danheld
# BithumbGlobal
# marcopologlobal
# cobie
# CryptoBull
# hodlonaut
# levijawn
# NexusOfficial
# TuurDemeester
# metaeconomia1
# MaxieRyan
# nwankwoesq
# Crypto_emrgency
# lopp
# AtomicWallet
# CryptoAdventure
# aantonop
# jchervinsky
# rektcapital
# woonomic
# crypto_birb
# TheMoonCarl
# cryptoshion
# DraxFTW_
# CryptoHayes
# Excellion
# btc
# Rhythmtrader
# nvk
# scottmelker
# WhalePanda
# crypto
# bgarlinghouse
# lightning
# ...

# %%
usuarios_personalidades = []
for i in db.personality_test.find():
    usuarios_personalidades.append(i)

# %%
aux = []
for i in usuarios_personalidades:
    i["user"] = i['user'].replace("@","")
    aux.append(i["user"])

# %%
usuarios_personalidades[0]["user"]
usuarios_personalidades[0]["text"]
usuarios_personalidades[0]["personality"][0]
# Out:
# ['INTJ', 1.0, '0.0529', 'Introverted', 'Intuitive', 'Thinking', 'Judging']

# %%
for i in dados_:
    usuarios_cadastrados.append(i['user'])

# %%
import csv

# open the file in the write mode
f = open('Dados_att3.csv', 'w', newline='',encoding='UTF-8')

# create the csv writer
writer = csv.writer(f)
writer.writerow(['Usuario',
'Texto','Personalidade'
,'Valor_TfidfVectorizer',])
# write a row to the csv file
for i in dados_:
    writer.writerow([i["user"],
        i["text"],
        i["personality"][0][0],
        i["personality"][0][2]])

# close the file
f.close()
