# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn import datasets

import pandas as pd

# %%
df=pd.read_csv('Dados_Features.csv')

# %%
df['MACRO']
# Out:
# 0        NT
# 1        SP
# 2        NF
# 3       NaN
# 4        NF
#        ...
# 3778    NaN
# 3779    NaN
# 3780    NaN
# 3781    NaN
# 3782     NF
# Name: MACRO, Length: 3783, dtype: object

# %%
df = df.dropna(subset = ["MACRO"])
df
# Out:
#               Usuario  Quantidade_Retweets  Quantidade_Likes  \
# 0          APompliano               314654           2564686
# 1     CoinCornerDanny                 6030             39698
# 2      AltcoinDailyio                17715            116982
# 4          cz_binance                95670            675162
# 8      GoingParabolic                 8724             74153
# ...               ...                  ...               ...
# 2547      limitstream                 4584              2258
# 2573      feminist_co                12735              8320
# 2681      Sonnenshein                 1158              9211
# 2894    CedYoungelman                 3689             24798
# 3782    Wealth_Theory                  822              5779
#
#       Quantidade_Publicacoes  Maior_N_Retweets  Maior_N_Likes  Seguidores  \
# 0                        486               338            466     1583590
# 1                         20               330           1434       30269
# ...

# %%
df = df.reset_index(drop=True)
df
# Out:
#              Usuario  Quantidade_Retweets  Quantidade_Likes  \
# 0         APompliano               314654           2564686
# 1    CoinCornerDanny                 6030             39698
# 2     AltcoinDailyio                17715            116982
# 3         cz_binance                95670            675162
# 4     GoingParabolic                 8724             74153
# ..               ...                  ...               ...
# 473      limitstream                 4584              2258
# 474      feminist_co                12735              8320
# 475      Sonnenshein                 1158              9211
# 476    CedYoungelman                 3689             24798
# 477    Wealth_Theory                  822              5779
#
#      Quantidade_Publicacoes  Maior_N_Retweets  Maior_N_Likes  Seguidores  \
# 0                       486               338            466     1583590
# 1                        20               330           1434       30269
# ...

# %%
for i in range(len(df['MACRO'])):
    if df['MACRO'][i] == 'NT':
        df['MACRO'][i] = 0
    elif df['MACRO'][i] == 'NF':
        df['MACRO'][i] = 1
    elif df['MACRO'][i] == 'SJ':
        df['MACRO'][i] = 2
    elif df['MACRO'][i] == 'SP':
        df['MACRO'][i] = 3
# Out:
# C:\Users\paulo\AppData\Local\Temp\ipykernel_6160\1474855534.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MACRO'][i] = 0
# C:\Users\paulo\AppData\Local\Temp\ipykernel_6160\1474855534.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MACRO'][i] = 3
# C:\Users\paulo\AppData\Local\Temp\ipykernel_6160\1474855534.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MACRO'][i] = 1
# ...

# %%
X = df[['Quantidade_Retweets','Quantidade_Likes','Quantidade_Publicacoes','Maior_N_Retweets','Maior_N_Likes','Seguidores','Amigos','Verificado']].values
X
# Out:
# array([[314654, 2564686, 486, ..., 1583590, 6681, True],
#        [6030, 39698, 20, ..., 30269, 2573, False],
#        [17715, 116982, 43, ..., 1139226, 535, False],
#        ...,
#        [1158, 9211, 5, ..., 113887, 1083, True],
#        [3689, 24798, 11, ..., 12787, 5577, False],
#        [822, 5779, 4, ..., 208864, 244, False]], dtype=object)

# %%
y = df["MACRO"].values
y=y.astype('int')

# %%
# linear regression feature importance
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from matplotlib import pyplot
# define dataset
model = XGBRegressor()
# fit the model
model.fit(X, y)
# get importance
importance = model.feature_importances_
# summarize feature importance
print(['Quantidade_Retweets','Quantidade_Likes','Quantidade_Publicacoes','Maior_N_Retweets','Maior_N_Likes','Seguidores','Amigos','Verificado'])
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# ['Quantidade_Retweets', 'Quantidade_Likes', 'Quantidade_Publicacoes', 'Maior_N_Retweets', 'Maior_N_Likes', 'Seguidores', 'Amigos', 'Verificado']
# Feature: 0, Score: 0.08239
# Feature: 1, Score: 0.09268
# Feature: 2, Score: 0.21263
# Feature: 3, Score: 0.09667
# Feature: 4, Score: 0.15907
# Feature: 5, Score: 0.16027
# Feature: 6, Score: 0.12265
# Feature: 7, Score: 0.07364

# %%
from sklearn import metrics

# %%
X[0].reshape(1,8)
# Out:
# array([[314654, 2564686, 486, 338, 466, 1583590, 6681, True]],
#       dtype=object)

# %%
y[1]
# Out:
# 3

# %%
model.predict(X[1].reshape(1,8))
# Out:
# array([2.982986], dtype=float32)
