# %% [markdown]
# ## Checagem de valores (likes,retweets,comentarios)

# %%
import pandas as pd
import pymongo
from bson.objectid import ObjectId
import csv

client = pymongo.MongoClient("mongodb+srv://trality:paulo123@cluster0.nbdde.mongodb.net/2020_Bitcoin_name?retryWrites=true&w=majority")
db = client.Bitcoin_

import tweepy

auth = tweepy.OAuthHandler("68IkXZgwKnnmRItm8mKjjwYtC", "ehGx3OCmUS7NbD3b3miqfRd6Vy1fwU8MMKbgcvG7yVFCNNLU8v")
auth.set_access_token("1167543680846221312-9G991V5lACwi9viZYO3WGWnDJNGqkt", "FgUL3Z1BYt3szn52jtQBp5MYpiU3lP4lrvJZwXVmMNDTc")

api = tweepy.API(auth)

import nltk
import re
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/paulo/Desktop/Faculdade/Faculdade/LCDIA/Checagem_valores.ipynb Cell 2' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/home/paulo/Desktop/Faculdade/Faculdade/LCDIA/Checagem_valores.ipynb#ch0000001?line=2'>3</a> from bson.objectid import ObjectId
#       <a href='vscode-notebook-cell:/home/paulo/Desktop/Faculdade/Faculdade/LCDIA/Checagem_valores.ipynb#ch0000001?line=3'>4</a> import csv
# ----> <a href='vscode-notebook-cell:/home/paulo/Desktop/Faculdade/Faculdade/LCDIA/Checagem_valores.ipynb#ch0000001?line=5'>6</a> client = pymongo.MongoClient("mongodb+srv://trality:paulo123@cluster0.nbdde.mongodb.net/2020_Bitcoin_name?retryWrites=true&w=majority")
#       <a href='vscode-notebook-cell:/home/paulo/Desktop/Faculdade/Faculdade/LCDIA/Checagem_valores.ipynb#ch0000001?line=6'>7</a> db = client.Bitcoin_
# ...

# %%
import pandas as pd

p2020 = pd.read_csv("Data_2020_Final.csv",sep=',',header=0)
p2021 = pd.read_csv("Data_2021_Final.csv",sep=',',header=0)

# %%
usuarios = []
for i in p2020.get('url'):
    usuarios.append(i)
for i in p2021.get('url'):
    usuarios.append(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\paulo\Desktop\Faculdade\LCDIA\Checagem_valores.ipynb Cell 4' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/paulo/Desktop/Faculdade/LCDIA/Checagem_valores.ipynb#ch0000003?line=0'>1</a> usuarios = []
# ----> <a href='vscode-notebook-cell:/c%3A/Users/paulo/Desktop/Faculdade/LCDIA/Checagem_valores.ipynb#ch0000003?line=1'>2</a> for i in p2020.get('url'):
#       <a href='vscode-notebook-cell:/c%3A/Users/paulo/Desktop/Faculdade/LCDIA/Checagem_valores.ipynb#ch0000003?line=2'>3</a>     usuarios.append(i)
#       <a href='vscode-notebook-cell:/c%3A/Users/paulo/Desktop/Faculdade/LCDIA/Checagem_valores.ipynb#ch0000003?line=3'>4</a> for i in p2021.get('url'):
#
# NameError: name 'p2020' is not defined

# %%
usuarios[0][usuarios[0].rfind("/")+1:]
# Out:
# '1233897470377238530'

# %%
f = open("ids_usuarios.txt", "a")
for i in range(len(usuarios)):
    f.write(usuarios[i][usuarios[i].rfind("/")+1:])
    f.write("\n")
f.close()

# %%
data = pd.read_csv('ids_usuarios.txt', sep=" ", header=None)

# %%
len(data[0])
# Out:
# 18791

# %%
import time

Usuarios_Cadastrados = []

for i in db.financial_stats.find():
    Usuarios_Cadastrados.append(i.get("text"))

for i in data[0][17000:]:
    try:
        aux = api.get_status(i)
        
        if aux._json["text"] not in Usuarios_Cadastrados:
            db.lcdia_tweets.insert_one(aux._json)
    except:
        print(i)
    time.sleep(0.5)
# Out:
# 1444281893135003656
# 1443978322598375428
# 1464952532443316230
# 1464579051662700546
# 1464372000978128898
# 1464355785157185538
# 1464249285025882114
# 1464172086994391059
# 1464024108623040522
# 1464021320279244805
# 1463840249352650755
# 1463546291057790977
# 1463504081025224706
# 1463413340680589314
# 1463396489204420608
# 1463283746602373130
# 1462401170371133446
# 1462283623638384640
# 1462086479140765704
# 1462063161033453570
# 1462061615180759041
# 1461733685892366342
# 1461379895007850501
# 1461258045011509251
# 1461255752903917573
# 1461193147745292292
# 1461104195700994050
# 1461067127394287617
# 1461045594571612172
# 1461044758542008327
# 1461041551019327489
# 1461040085898567688
# 1461036244872400907
# 1461035195046498307
# 1461030634957283329
# 1461028792248541190
# 1461027874949922818
# 1460987063608741894
# 1460984822994804742
# 1460982222471716869
# 1460980413116174336
# 1460976202542370824
# 1460971840986308609
# 1460965945699188739
# 1460964306909110272
# ...

# %%
db.Altcoins.insert_one(Trades)

# %%
aux
# Out:
# Status(_api=<tweepy.api.API object at 0x0000027AE45AA680>, _json={'created_at': 'Sat Feb 29 23:30:56 +0000 2020', 'id': 1233897470377238530, 'id_str': '1233897470377238530', 'text': 'I want everyone to learn about Bitcoin.\n\nTo move us closer to that reality, I’m giving out 5 free subscriptions to… https://t.co/l0uoYhqdA8', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/l0uoYhqdA8', 'expanded_url': 'https://twitter.com/i/web/status/1233897470377238530', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 339061487, 'id_str': '339061487', 'name': 'Pomp 🌪', 'screen_name': 'APompliano', 'location': 'Global', 'description': 'I invest
# ...

# %%
data[0][1]
# Out:
# 1233884185485545472

# %%
aux = api.get_status(data[0][1])

# %%
import json

aux._json["text"]
# Out:
# '#Bitcoin price on 29th February\n\n2012: $5\n2016: $436\n2020: $8,625'

# %%
lcida_textos = db.lcdia_tweets.find()

# %%
Usuarios_Cadastrados = []

for i in db.financial_stats.find():
    Usuarios_Cadastrados.append(i.get("text"))

# %%
Usuarios_Cadastrados
# Out:
# ['I want everyone to learn about Bitcoin.\n\nTo move us closer to that reality, I’m giving out 5 free subscriptions to the daily letter I write to 40,000 investors.\n\nRetweet this tweet and subscribe at this link to be considered for the free subscription: http://offthechain.substack.com',
#  '#Bitcoin price on 29th February\n\n2012: $5\n2016: $436\n2020: $8,625',
#  "BREAKING: In a landmark case, an Australian judge has JUST ruled #Bitcoin to be a legitimate investment vehicle that can be used as financial collateral.\n\nThis means bitcoin is just as legal as fiat. With just as clear use case as fiat. Legally.\n\nIt's happening ",
#  'NanoGames is giving away another $300 in Bitcoin and NANO this weekend!\n\nJoin our Live Game Chat  https://NanoGames.io\n\nHelp us spread the word for a chance to win one of five $10  prizes.\n\nFollow, Like and Retweet w/ your $NANO or #bitcoin wallet address.',
#  'You can’t fake #bitcoin.',
# ...
