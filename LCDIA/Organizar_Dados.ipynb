# %%
import pandas as pd
import pymongo
from bson.objectid import ObjectId
import csv

client = pymongo.MongoClient("mongodb+srv://trality:paulo123@cluster0.nbdde.mongodb.net/2020_Bitcoin_name?retryWrites=true&w=majority")
db = client.Bitcoin_

import tweepy

auth = tweepy.OAuthHandler("68IkXZgwKnnmRItm8mKjjwYtC", "ehGx3OCmUS7NbD3b3miqfRd6Vy1fwU8MMKbgcvG7yVFCNNLU8v")
auth.set_access_token("1167543680846221312-9G991V5lACwi9viZYO3WGWnDJNGqkt", "FgUL3Z1BYt3szn52jtQBp5MYpiU3lP4lrvJZwXVmMNDTc")

api = tweepy.API(auth)

import nltk
import re
from sklearn.feature_extraction.text import TfidfVectorizer
import string
from nltk.corpus import stopwords

# %%
Usuarios_Cadastrados = []

for i in db.lcdia_tweets_correto.find():
    Usuarios_Cadastrados.append(i)

# %%
from collections import Counter

#Counter(Valores).most_common()

# %%
Usuarios_Cadastrados[0]['retweet_count']
Usuarios_Cadastrados[0]['favorite_count']
Usuarios_Cadastrados[0]['user']['followers_count']
Usuarios_Cadastrados[0]['user']['friends_count']
# Out:
# {'_id': ObjectId('626614abdfd0b632464f08b8'),
#  'created_at': 'Sat Feb 29 23:30:56 +0000 2020',
#  'id': 1233897470377238530,
#  'id_str': '1233897470377238530',
#  'text': 'I want everyone to learn about Bitcoin.\n\nTo move us closer to that reality, I’m giving out 5 free subscriptions to… https://t.co/l0uoYhqdA8',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/l0uoYhqdA8',
#     'expanded_url': 'https://twitter.com/i/web/status/1233897470377238530',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [116, 139]}]},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 339061487,
#   'id_str': '339061487',
#   'name': 'Pomp 🌪',
# ...

# %%
dict_ = {}
for i in Usuarios_Cadastrados:
    aux = i['user']['screen_name']
    if aux not in dict_:
        #retweets/likes/publicacoes/maior_retweet/maior_likes/seguidores/amigos/verificado
        dict_[aux] = [aux,0,0,0,0,0,0,0,0]
        dict_[aux][1] =  i['retweet_count']
        dict_[aux][2] =  i['favorite_count']
        dict_[aux][3] += 1
        dict_[aux][4] =  i['retweet_count']
        dict_[aux][5] =  i['favorite_count']
        dict_[aux][6] =  i['user']['followers_count']
        dict_[aux][7] =  i['user']['friends_count']
        dict_[aux][8] =  i['user']['verified']
    else: 
        dict_[aux][3] += 1
        dict_[aux][1] +=  i['retweet_count']
        dict_[aux][2] +=  i['favorite_count']

        if dict_[aux][1] < i['retweet_count']:
            dict_[aux][4] =  i['retweet_count']
        if dict_[aux][2] < i['favorite_count']:
            dict_[aux][5] =  i['favorite_count']

# %%
dict_
# Out:
# {'APompliano': ['APompliano',
#   314654,
#   2564686,
#   486,
#   338,
#   466,
#   1582266,
#   6681,
#   True],
#  'CoinCornerDanny': ['CoinCornerDanny',
#   6030,
#   39698,
#   20,
#   330,
#   1434,
#   30272,
#   2573,
#   False],
#  'AltcoinDailyio': ['AltcoinDailyio',
#   17715,
#   116982,
#   43,
#   748,
#   2808,
#   1138630,
#   535,
#   False],
#  'nanogamesio': ['nanogamesio', 276, 377, 1, 276, 377, 11527, 42, False],
#  'cz_binance': ['cz_binance',
#   95670,
#   675162,
#   106,
#   530,
#   1954,
#   5667498,
#   1718,
#   True],
#  'faveladoinvest': ['faveladoinvest',
#   222,
#   2305,
#   1,
#   222,
#   2305,
#   130963,
#   319,
#   False],
#  'DexiveExchange': ['DexiveExchange', 406, 368, 1, 406, 368, 378, 0, False],
#  'river': ['river', 229, 769, 1, 229, 769, 17760, 81, True],
#  'GoingParabolic': ['GoingParabolic',
#   8724,
#   74153,
#   32,
#   458,
#   444,
#   191256,
#   607,
#   False],
# ...

# %%
for i in dict_:
    dict_[i][1] = int(dict_[i][1])
    dict_[i][2] = int(dict_[i][2])
    dict_[i][3] = int(dict_[i][3])
    dict_[i][4] = int(dict_[i][4])
    dict_[i][5] = int(dict_[i][5])
    dict_[i][6] = int(dict_[i][6])
    dict_[i][6] = int(dict_[i][7])

# %%
import csv

# open the file in the write mode
f = open('Usuarios_correto.csv', 'w', newline='',encoding='UTF-8')

# create the csv writer
writer = csv.writer(f)
writer.writerow(['Usuario',
'Quantidade_Retweets','Quantidade_Likes'
,'Maior_N_Retweets','Maior_N_Likes','Seguidores',
'Amigos','Verificado'])
# write a row to the csv file
for i in dict_:
    writer.writerow(dict_[i])

# close the file
f.close()
